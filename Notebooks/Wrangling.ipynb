# %%
# Core
import re, os, sys, string, random, functools
import pandas as pd
from pathlib import Path
import numpy as np
# Stats
import scipy.stats as stats
# Reduce warnings
import warnings
warnings.filterwarnings("ignore") # usually not a good idea!

# %% [markdown]
# ## Data wrangling
# ### Desert Botanic Garden
# These data were collected by Karolina and I in the spring of 2019. I already compiled the data somewhere else, so it can be easily loaded.

# %%
nonCAMcolor = "xkcd:light eggplant"
intCAMcolor = "xkcd:apricot"
pCAMcolor = "xkcd:lichen"
cmap = {"C3":nonCAMcolor, "C4":nonCAMcolor,"C3-C4":nonCAMcolor, "CAM":pCAMcolor, "C3-C4+CAM":intCAMcolor, "C4+CAM":intCAMcolor, "C3+CAM":intCAMcolor}

# %%
dbg = pd.read_csv("../Data/DBG-Measurements.csv")
dbg = dbg.rename({"mesophyll_cell_area_um2":"MAmean (um^2)", 
            "mesophyll_cell_area_um2_SE":"MAse (um^2)",
            "leaf_thickness_um":"LTmean (um)",
            "leaf_thickness_um_SE": "LTse (um)",
            "IAS":"IASmean (%)",
            "IAS_SE":"IASse (%)",}, axis=1)
dbg["Reference"] = "This publication"
dbg["color"] = [cmap[p] for p in dbg["Pathway"]]
dbg["Source"] = "DBG"
dbg.head()
# Out:
#   MajorLineage  Genus      Species              Taxon Tissue Pathway  \
# 0   Agavoideae  Agave    americana    Agave americana   Leaf     CAM
# 1   Agavoideae  Agave    americana    Agave americana   Leaf     CAM
# 2   Agavoideae  Agave    americana    Agave americana   Leaf     CAM
# 3   Agavoideae  Agave    attenuata    Agave attenuata   Leaf     CAM
# 4   Agavoideae  Agave  bovicornuta  Agave bovicornuta   Leaf     CAM
#
#    MAmean (um^2)  MAse (um^2)  LTmean (um)   LTse (um)  IASmean (%)  \
# 0    1339.683455    20.391867  4887.368333   51.895283     0.047124
# 1    2212.446822    36.936013  3204.702000   17.616073     0.061181
# 2    3090.210853    53.191428  4402.634667  114.466009     0.180749
# 3    3013.052933   175.556512  2935.331667   57.566621          NaN
# 4    3223.139679    84.612126  2729.777000   82.985558     0.039694
#
#    IASse (%)         Reference        color Source
# 0   0.013377  This publication  xkcd:lichen    DBG
# 1   0.024675  This publication  xkcd:lichen    DBG
# 2   0.050523  This publication  xkcd:lichen    DBG
# 3        NaN  This publication  xkcd:lichen    DBG
# 4   0.009803  This publication  xkcd:lichen    DBG

# %%
dbg[["Taxon","Pathway"]].drop_duplicates()["Pathway"].value_counts()
# Out:
# CAM       60
# C3        12
# C3+CAM     7
# Name: Pathway, dtype: int64

# %% [markdown]
# ### Other Edwards' lab data
# These sections were prepared by Lily and Elissa in 2017. They are mostly _Parakeelya_ (Australian _Calandrinia_), but there are other Portulacineae too.

# %%
elDir = Path("../Data/Edwards-Lab-Unpublished/")
elFiles = list(elDir.rglob("*.csv"))

# %%
genus = []
species = []
iasMean = []
iasSE = []
thicknessMean = []
thicknessSE = []
mAreaMean = []
mAreaSE = []

for p in elFiles:
    g,s,_ =  p.stem.split("-")
    genus.append(g)
    species.append(s)
    
    df = pd.read_csv(p)
    df.dropna(how="all")
    
    iasVals = []
    for c in df.columns:
        if (c.lower().startswith("ias")) and (len(df[c].dropna() > 0)):
            series = df[c].dropna()
            ias = series[1:].sum()/series[0]
            iasVals.append(ias)
            del ias
            
        elif c.lower().startswith("thickness"):
            if len(df[c].dropna()) > 0:
                ts  = []
                for t in df[c].dropna():
                    try:
                        ts.append(float(t))
                    except:
                        continue
                thicknessMean.append(np.mean(ts))
                thicknessSE.append(stats.sem(ts))
            else:
                thicknessMean.append(np.nan)
                thicknessSE.append(np.nan)
            
        elif "um^" in c.lower():
            if len(df[c].dropna()) > 0:
                mAreaMean.append(df[c].dropna().mean())
                mAreaSE.append(stats.sem(df[c].dropna()))
            else:
                mAreaMean.append(np.nan)
                mAreaSE.append(np.nan)
                
    if len(iasVals) > 0:
        iasMean.append(np.mean(iasVals))
        iasSE.append(stats.sem(iasVals))
    else:
        iasMean.append(np.nan)
        iasSE.append(np.nan)
    del iasVals
    
elDF = pd.DataFrame()
elDF["Genus"] = genus
elDF["Species"] = species
elDF["Taxon"] = elDF["Genus"] + " " + elDF["Species"]
elDF["IASmean (%)"] = iasMean
elDF["IASse (%)"] = iasSE
elDF["LTmean (um)"] = thicknessMean
elDF["LTse (um)"] = thicknessSE
elDF["MAmean (um^2)"] = mAreaMean
elDF["MAse (um^2)"] = mAreaSE
elDF["MajorLineage"] = "Montiaceae"
elDF.loc[elDF["Genus"]=="Anacampseros", "MajorLineage"] = "Anacampserotaceae"
elDF.loc[elDF["Genus"]=="Alluaudia", "MajorLineage"] = "Didiereaceae"
elDF.loc[elDF["Genus"]=="Anredera", "MajorLineage"] = "Basellaceae"
elDF["Pathway"] = "C3+CAM"
elDF.loc[elDF["Genus"]=="Alluaudia", "Pathway"] = "CAM"
elDF.loc[elDF["Species"].isin(["tumida","granulifera","arenicola"]), "Pathway"] = "C3"
elDF["Tissue"] = "leaf"
elDF["Reference"] = "This publication"
elDF["color"] = [cmap[p] for p in elDF["Pathway"]]
elDF["Source"] = "Edwards Lab unpublished"
elDF
# Out:
#            Genus       Species                     Taxon  IASmean (%)  \
# 0   Anacampseros    lanceolata   Anacampseros lanceolata     0.115410
# 1    Calandrinia  schistorhiza  Calandrinia schistorhiza     0.386109
# 2    Calandrinia         flava         Calandrinia flava     0.254209
# 3      Alluaudia       procera         Alluaudia procera     0.037015
# 4   Anacampseros     rufescens    Anacampseros rufescens     0.062892
# 5    Calandrinia    linliflora    Calandrinia linliflora     0.126511
# 6    Calandrinia  kalanniensis  Calandrinia kalanniensis     0.158303
# 7    Calandrinia  spergularina  Calandrinia spergularina     0.151830
# 8    Calandrinia  quadrivalvis  Calandrinia quadrivalvis     0.296044
# 9    Calandrinia   brevipedata   Calandrinia brevipedata          NaN
# 10   Calandrinia        tumida        Calandrinia tumida          NaN
# 11   Calandrinia        pumila        Calandrinia pumila     0.349628
# 12      Anredera   baselloides      Anredera baselloides          NaN
# 13   Calandrinia   pentavalvis   Calandrinia pentavalvis     0.181312
# 14   Calandrinia   pleiopetala   Calandrinia pleiopetala     0.076247
#
#     IASse (%)  LTmean (um)   LTse (um)  MAmean (um^2)  MAse (um^2)  \
# 0    0.029697  2471.649000    3.131274    5386.652900   533.753571
# 1    0.032014  2201.309667  116.701903    5845.797059   539.551182
# 2    0.037023  2121.204667  110.127142   15824.965100  1569.959482
# 3    0.013922   650.387333   19.058869    2687.575767   199.017468
# 4    0.001657          NaN         NaN    5465.068933   667.258109
# 5    0.011174   748.170000   52.404524    4140.029333   265.364358
# 6    0.060582  1420.455500   12.745901    5820.995133   582.214644
# 7    0.045947  1628.278000   37.424043   10034.584000   545.033741
# 8    0.014849  2125.910333   96.829656    6468.855526   520.271300
# 9         NaN  1327.972500   23.652313    7948.507400   488.056140
# 10        NaN  1303.287667   36.051382    5559.895636   457.719247
# 11   0.044495   879.002000   51.768957    9770.986700   481.301961
# 12        NaN   604.501500   18.556103    5391.115750   473.960490
# 13   0.065684  1872.605333   50.845305    6678.694500   627.425657
# 14   0.017686          NaN         NaN    6427.563000   353.846389
#
#          MajorLineage Pathway Tissue         Reference                color  \
# 0   Anacampserotaceae  C3+CAM   leaf  This publication         xkcd:apricot
# 1          Montiaceae  C3+CAM   leaf  This publication         xkcd:apricot
# 2          Montiaceae  C3+CAM   leaf  This publication         xkcd:apricot
# 3        Didiereaceae     CAM   leaf  This publication          xkcd:lichen
# 4   Anacampserotaceae  C3+CAM   leaf  This publication         xkcd:apricot
# 5          Montiaceae  C3+CAM   leaf  This publication         xkcd:apricot
# 6          Montiaceae  C3+CAM   leaf  This publication         xkcd:apricot
# 7          Montiaceae  C3+CAM   leaf  This publication         xkcd:apricot
# 8          Montiaceae  C3+CAM   leaf  This publication         xkcd:apricot
# 9          Montiaceae  C3+CAM   leaf  This publication         xkcd:apricot
# 10         Montiaceae      C3   leaf  This publication  xkcd:light eggplant
# 11         Montiaceae  C3+CAM   leaf  This publication         xkcd:apricot
# 12        Basellaceae  C3+CAM   leaf  This publication         xkcd:apricot
# 13         Montiaceae  C3+CAM   leaf  This publication         xkcd:apricot
# 14         Montiaceae  C3+CAM   leaf  This publication         xkcd:apricot
#
#                      Source
# 0   Edwards Lab unpublished
# 1   Edwards Lab unpublished
# 2   Edwards Lab unpublished
# 3   Edwards Lab unpublished
# 4   Edwards Lab unpublished
# 5   Edwards Lab unpublished
# 6   Edwards Lab unpublished
# 7   Edwards Lab unpublished
# 8   Edwards Lab unpublished
# 9   Edwards Lab unpublished
# 10  Edwards Lab unpublished
# 11  Edwards Lab unpublished
# 12  Edwards Lab unpublished
# 13  Edwards Lab unpublished
# 14  Edwards Lab unpublished

# %%
elDF[["Taxon","Pathway"]].drop_duplicates()["Pathway"].value_counts()
# Out:
# C3+CAM    13
# CAM        1
# C3         1
# Name: Pathway, dtype: int64

# %% [markdown]
# ### _Portulaca_ images
# These images were shared by Dr. Elena Voznesenskaya and were originally published in multiple works with Dr. Gilberto Ocampo on _Portulaca_ leaf ultrastructure (Ocampo _et al._, 2013; Vozneenskaya _et al._, 2010, 2017)

# %%
portDir = Path("../Data/Portulaca-Ocampo-2013/")
portFiles = list(portDir.rglob("*.csv"))

# %%
genus = []
species = []
iasMean = []
iasSE = []
thicknessMean = []
thicknessSE = []
mAreaMean = []
mAreaSE = []

for p in portFiles:
    g,s =  p.stem.split("-")[:2]
    genus.append(g)
    species.append(s)
    
    df = pd.read_csv(p)
    df.dropna(how="all")
    
    iasVals = []
    for c in df.columns:
        if (c.lower().startswith("ias")) and (len(df[c].dropna() > 0)):
            series = df[c].dropna()
            ias = series[1:].sum()/series[0]
            iasVals.append(ias)
            del ias
            
        elif c.lower().startswith("thickness"):
            if len(df[c].dropna()) > 0:
                ts  = []
                for t in df[c].dropna():
                    try:
                        ts.append(float(t))
                    except:
                        continue
                thicknessMean.append(np.mean(ts))
                thicknessSE.append(stats.sem(ts))
            else:
                thicknessMean.append(np.nan)
                thicknessSE.append(np.nan)
            
        elif "um^" in c.lower():
            if len(df[c].dropna()) > 0:
                mAreaMean.append(df[c].dropna().mean())
                mAreaSE.append(stats.sem(df[c].dropna()))
            else:
                mAreaMean.append(np.nan)
                mAreaSE.append(np.nan)
                
    if len(iasVals) > 0:
        iasMean.append(np.mean(iasVals))
        iasSE.append(stats.sem(iasVals))
    else:
        iasMean.append(np.nan)
        iasSE.append(np.nan)
    del iasVals
    
portDF = pd.DataFrame()
portDF["Genus"] = genus
portDF["Species"] = species
portDF["Taxon"] = portDF["Genus"] + " " + portDF["Species"]
portDF["IASmean (%)"] = iasMean
portDF["IASse (%)"] = iasSE
portDF["LTmean (um)"] = thicknessMean
portDF["LTse (um)"] = thicknessSE
portDF["MAmean (um^2)"] = mAreaMean
portDF["MAse (um^2)"] = mAreaSE
portDF["MajorLineage"] = "Portulacaceae"
portDF["Pathway"] = "C4+CAM"
portDF.loc[portDF["Species"].isin(["cryptopetala","hirsutissima", "mucronata"]), "Pathway"] = "C3-C4+CAM"
portDF["Tissue"] = "leaf"
portDF["Reference"] = "Ocampo et al., 2013; Voznesenskaya et al., 2010, 2017"
portDF["color"] = [cmap[p] for p in portDF["Pathway"]]
portDF["Source"] = "Voznesenskaya"
portDF
# Out:
#         Genus        Species                    Taxon  IASmean (%)  IASse (%)  \
# 0   Portulaca         biloba         Portulaca biloba     0.228076   0.059172
# 1   Portulaca  suffrutescens  Portulaca suffrutescens     0.093388   0.001908
# 2   Portulaca       giliesii       Portulaca giliesii     0.170300   0.056221
# 3   Portulaca     halimoides     Portulaca halimoides     0.061723   0.033373
# 4   Portulaca        elatior        Portulaca elatior          NaN        NaN
# 5   Portulaca   hirsutissima   Portulaca hirsutissima     0.228079   0.041216
# 6   Portulaca        bicolor        Portulaca bicolor          NaN        NaN
# 7   Portulaca      mucronata      Portulaca mucronata     0.110991   0.002283
# 8   Portulaca         pilosa         Portulaca pilosa     0.056052   0.004676
# 9   Portulaca   cryptopetala   Portulaca cryptopetala     0.122930   0.038382
# 10  Portulaca       oleracea       Portulaca oleracea     0.163114   0.034217
# 11  Portulaca  molokiniensis  Portulaca molokiniensis     0.065683   0.025173
# 12  Portulaca    umbraticola    Portulaca umbraticola     0.063284   0.007480
# 13  Portulaca        smallii        Portulaca smallii     0.136362   0.035186
# 14  Portulaca    umbraticola    Portulaca umbraticola     0.104581   0.029042
#
#     LTmean (um)  LTse (um)  MAmean (um^2)  MAse (um^2)   MajorLineage  \
# 0    614.595667  18.489551    1066.389267    97.628145  Portulacaceae
# 1    624.067333   5.313150     614.224150    42.833571  Portulacaceae
# 2    958.208000   8.941161    2331.649000   232.395388  Portulacaceae
# 3    714.675333  19.040694    2319.560000   118.023122  Portulacaceae
# 4    553.904167  26.920341     895.186187    71.971800  Portulacaceae
# 5   1612.173333  15.320234    3615.746600   394.487793  Portulacaceae
# 6   3480.241000  30.212094     559.431154    39.757293  Portulacaceae
# 7    646.551667  12.893469    5698.374867   606.384711  Portulacaceae
# 8   2019.628333  29.777352    1914.744867   174.199251  Portulacaceae
# 9   1334.973333   9.248129    2054.263933   225.274919  Portulacaceae
# 10   500.527000   7.552910     715.778267    50.014140  Portulacaceae
# 11   785.626333   3.526183    1085.718600   128.890289  Portulacaceae
# 12   701.366333  15.008983    1223.582850   109.101728  Portulacaceae
# 13   767.233667  14.141636     782.659000    78.135355  Portulacaceae
# 14   711.237000  12.568455     791.241400    55.296105  Portulacaceae
#
#       Pathway Tissue                                          Reference  \
# 0      C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 1      C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 2      C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 3      C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 4      C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 5   C3-C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 6      C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 7   C3-C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 8      C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 9   C3-C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 10     C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 11     C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 12     C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 13     C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
# 14     C4+CAM   leaf  Ocampo et al., 2013; Voznesenskaya et al., 201...
#
#            color         Source
# 0   xkcd:apricot  Voznesenskaya
# 1   xkcd:apricot  Voznesenskaya
# 2   xkcd:apricot  Voznesenskaya
# 3   xkcd:apricot  Voznesenskaya
# 4   xkcd:apricot  Voznesenskaya
# 5   xkcd:apricot  Voznesenskaya
# 6   xkcd:apricot  Voznesenskaya
# 7   xkcd:apricot  Voznesenskaya
# 8   xkcd:apricot  Voznesenskaya
# 9   xkcd:apricot  Voznesenskaya
# 10  xkcd:apricot  Voznesenskaya
# 11  xkcd:apricot  Voznesenskaya
# 12  xkcd:apricot  Voznesenskaya
# 13  xkcd:apricot  Voznesenskaya
# 14  xkcd:apricot  Voznesenskaya

# %%
dbg[["Taxon","Pathway"]].merge(elDF[["Taxon","Pathway"]], on=["Taxon","Pathway"], how="outer").merge(portDF[["Taxon","Pathway"]],on=["Taxon","Pathway"],how="outer").drop_duplicates()['Pathway'].value_counts()
# Out:
# CAM          61
# C3+CAM       20
# C3           13
# C4+CAM       11
# C3-C4+CAM     3
# Name: Pathway, dtype: int64

# %% [markdown]
# ### Orgburn and Edwards (2012)

# %%
mogs = pd.read_csv("../Data/Ogburn/leaf_data2.tsv", sep="\t", usecols=["taxon", "palisade_cellsize", "leaf_thickness","ias_by_area"])
mogs = mogs.groupby("taxon").mean().reset_index()
mogs["MAmean (um^2)"] = mogs["palisade_cellsize"]*1000*1000
mogs["LTmean (um)"] = mogs["leaf_thickness"]*1000
mogs = mogs.rename({"ias_by_area":"IASmean (%)", "taxon":"Taxon"},axis=1)
mogs = mogs.drop(["palisade_cellsize", "leaf_thickness"],axis=1)
mogs["Taxon"] = [t.replace("_"," ") for t in mogs["Taxon"]]
mogs["Genus"] = [t.split()[0] for t in mogs["Taxon"]]
mogs["Species"] = [t.split()[1] for t in mogs["Taxon"]]
mogs["MajorLineage"] = ""
mogs["Reference"] = "Ogburn and Edwards (2012); Ogburn and Edwards (2013)"
mogs["Pathway"] = ""

mogs.sort_values(by=["Taxon"])
# Out:
#                         Taxon  IASmean (%)  MAmean (um^2)  LTmean (um)  \
# 0       Adenogramma glomerata     0.237898     600.000000   263.969200
# 1           Alluaudia procera     0.030253    2915.285714   575.846200
# 2    Anacampseros australiana          NaN    4629.500000   850.275000
# 3     Anacampseros lanceolata     0.114036    6660.307692  2070.560143
# 4      Anacampseros rufescens          NaN            NaN  1867.400333
# 5        Anacampseros subnuda          NaN            NaN  3525.701000
# 6        Anredera baselloides     0.142392    6811.000000   585.683333
# 7     Calandrinia axilliflora          NaN    5876.200000   728.927000
# 8   Calandrinia colchaguensis          NaN    2873.111111   927.270400
# 9     Calyptridium umbellatum          NaN    4222.428571  1137.763400
# 10        Ceraria fruticulosa          NaN    3426.166667   848.292000
# 11            Cistanthe picta          NaN    3052.666667  1363.320000
# 12      Cistanthe salsoloides     0.000293   13333.750000  3254.917000
# 13          Cistanthe tweedyi          NaN    4938.400000   876.123667
# 14        Claytonia megarhiza     0.282108    5804.375000   887.301400
# 15         Grahamia bracteata          NaN   10731.500000  1960.000000
# 16       Halophytum ameghinoi     0.207606   14205.300000  3736.362667
# 17     Hypertelis salsoloides          NaN    1636.500000  1016.106400
# 18         Lewisia columbiana          NaN    2252.375000   813.830400
# 19           Limeum africanum          NaN            NaN   891.444400
# 20       Mirabilis nyctaginea          NaN    2640.875000   332.800200
# 21           Mollugo cerviana          NaN     486.250000   187.530000
# 22            Mollugo tenella          NaN            NaN   426.841667
# 23       Mollugo verticillata          NaN            NaN   347.998333
# 24            Montia linearis          NaN    1545.750000   570.344000
# 25          Montia parvifolia          NaN            NaN   392.975000
# 26        Montiopsis andicola          NaN            NaN   399.354167
# 27          Montiopsis gayana          NaN     867.750000   421.919800
# 28       Montiopsis gilliesii          NaN            NaN   503.301000
# 29          Pereskia aculeata          NaN    2740.000000   511.163333
# 30          Pereskia guamacho          NaN    9853.285714  1194.847000
# 31    Pereskia portulacifolia          NaN            NaN   635.480600
# 32         Pereskia sacharosa          NaN            NaN   743.537200
# 33         Pharnaceum incanum          NaN            NaN   348.990667
# 34    Pharnaceum microphyllum          NaN            NaN   523.317667
# 35    Phemeranthus napiformis          NaN            NaN  2217.372500
# 36    Phemeranthus spinescens          NaN            NaN   881.955667
# 37  Phemeranthus teretifolius          NaN    4715.875000  1716.385667
# 38         Portulaca oleracea          NaN            NaN   771.089600
# 39           Portulaca pilosa          NaN     712.000000   467.511800
# 40          Portulacaria afra          NaN    6548.375000  1567.242600
# 41    Quiabentia verticillata          NaN            NaN  4491.306000
# 42      Talinopsis frutescens          NaN   10656.833333  1603.961750
# 43            Talinum caffrum          NaN    3055.500000   573.455400
# 44         Talinum fruticosum          NaN    9968.875000   810.461800
# 45    Talinum portulacifolium          NaN    6073.700000   562.658667
#
#            Genus          Species MajorLineage  \
# 0    Adenogramma        glomerata
# 1      Alluaudia          procera
# 2   Anacampseros      australiana
# 3   Anacampseros       lanceolata
# 4   Anacampseros        rufescens
# 5   Anacampseros          subnuda
# 6       Anredera      baselloides
# 7    Calandrinia      axilliflora
# 8    Calandrinia    colchaguensis
# 9   Calyptridium       umbellatum
# 10       Ceraria      fruticulosa
# 11     Cistanthe            picta
# 12     Cistanthe      salsoloides
# 13     Cistanthe          tweedyi
# 14     Claytonia        megarhiza
# 15      Grahamia        bracteata
# 16    Halophytum        ameghinoi
# 17    Hypertelis      salsoloides
# 18       Lewisia       columbiana
# 19        Limeum        africanum
# 20     Mirabilis       nyctaginea
# 21       Mollugo         cerviana
# 22       Mollugo          tenella
# 23       Mollugo     verticillata
# 24        Montia         linearis
# 25        Montia       parvifolia
# 26    Montiopsis         andicola
# 27    Montiopsis           gayana
# 28    Montiopsis        gilliesii
# 29      Pereskia         aculeata
# 30      Pereskia         guamacho
# 31      Pereskia   portulacifolia
# 32      Pereskia        sacharosa
# 33    Pharnaceum          incanum
# 34    Pharnaceum     microphyllum
# 35  Phemeranthus       napiformis
# 36  Phemeranthus       spinescens
# 37  Phemeranthus     teretifolius
# 38     Portulaca         oleracea
# 39     Portulaca           pilosa
# 40  Portulacaria             afra
# 41    Quiabentia     verticillata
# 42    Talinopsis       frutescens
# 43       Talinum          caffrum
# 44       Talinum       fruticosum
# 45       Talinum  portulacifolium
#
#                                             Reference Pathway
# 0   Ogburn and Edwards (2012); Ogburn and Edwards ...
# 1   Ogburn and Edwards (2012); Ogburn and Edwards ...
# 2   Ogburn and Edwards (2012); Ogburn and Edwards ...
# 3   Ogburn and Edwards (2012); Ogburn and Edwards ...
# 4   Ogburn and Edwards (2012); Ogburn and Edwards ...
# 5   Ogburn and Edwards (2012); Ogburn and Edwards ...
# 6   Ogburn and Edwards (2012); Ogburn and Edwards ...
# 7   Ogburn and Edwards (2012); Ogburn and Edwards ...
# 8   Ogburn and Edwards (2012); Ogburn and Edwards ...
# 9   Ogburn and Edwards (2012); Ogburn and Edwards ...
# 10  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 11  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 12  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 13  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 14  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 15  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 16  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 17  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 18  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 19  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 20  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 21  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 22  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 23  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 24  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 25  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 26  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 27  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 28  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 29  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 30  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 31  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 32  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 33  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 34  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 35  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 36  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 37  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 38  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 39  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 40  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 41  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 42  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 43  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 44  Ogburn and Edwards (2012); Ogburn and Edwards ...
# 45  Ogburn and Edwards (2012); Ogburn and Edwards ...

# %% [markdown]
# I noticed that the IAS was suspiciously low for _Cistanthe salsoloides_ (0.0000293), so I remeasured it and got 0.13, a more reasonable value. I remeasured a few other taxa that had values that seemed a litte off (like the large MA of Montia linearis), but these all matched Matt's measurements. Still, I'll use my measurements for consistency below.

# %%
mogs.loc[mogs["Taxon"].isin(["Cistanthe salsoloides","Hypertelis salsoloides"]), "IASmean (%)"] = np.NaN
mogs.loc[mogs["Taxon"].isin(["Montia linearis","Hypertelis salsoloides", "Pereskia guamacho"]), "MAmean (um^2)"] = np.NaN
mogs = mogs[~mogs["Taxon"].isin(["Claytonia megarhiza"])]

# %% [markdown]
# I'll fill in missing measurements from the above. Not all traits were originally measured for all species.

# %%
mogsDir = Path("../Data/Ogburn/Remeasured/")
mogsFiles = [f for f in list(mogsDir.rglob("*.csv"))]

# %%
genus = []
species = []
iasMean = []
iasSE = []
thicknessMean = []
thicknessSE = []
mAreaMean = []
mAreaSE = []

for p in mogsFiles:
    g,s =  re.split("[0-9_-]",p.stem)[:2]
    genus.append(g)
    species.append(s)
    
    df = pd.read_csv(p)
    df.dropna(how="all")
    
    iasVals = []
    for c in df.columns:
        if (c.lower().startswith("ias")) and (len(df[c].dropna() > 0)):
            series = df[c].dropna()
            ias = series[1:].sum()/series[0]
            iasVals.append(ias)
            del ias
            
        elif c.lower().startswith("thickness"):
            if len(df[c].dropna()) > 0:
                ts  = []
                for t in df[c].dropna():
                    try:
                        ts.append(float(t))
                    except:
                        continue
                thicknessMean.append(np.mean(ts))
                thicknessSE.append(stats.sem(ts))
            else:
                thicknessMean.append(np.nan)
                thicknessSE.append(np.nan)
            
        elif "um^" in c.lower():
            if len(df[c].dropna()) > 0:
                mAreaMean.append(df[c].dropna().mean())
                mAreaSE.append(stats.sem(df[c].dropna()))
            else:
                mAreaMean.append(np.nan)
                mAreaSE.append(np.nan)
                
    if len(iasVals) > 0:
        iasMean.append(np.mean(iasVals))
        iasSE.append(stats.sem(iasVals))
    else:
        iasMean.append(np.nan)
        iasSE.append(np.nan)
    del iasVals
    
miscOgs = pd.DataFrame()
miscOgs["Genus"] = genus
miscOgs["Species"] = species
miscOgs["Taxon"] = miscOgs["Genus"] + " " + miscOgs["Species"]
miscOgs["IASmean (%)"] = iasMean
miscOgs["IASse (%)"] = iasSE
miscOgs["LTmean (um)"] = thicknessMean
miscOgs["LTse (um)"] = thicknessSE
miscOgs["MAmean (um^2)"] = mAreaMean
miscOgs["MAse (um^2)"] = mAreaSE
miscOgs["Reference"] = "Ogburns and Edwards (2012); Ogburns and Edwards (2013)"
miscOgs = miscOgs.merge(mogs[["Taxon","MajorLineage"]], on="Taxon", how="left")
miscOgs.sort_values("Taxon")
# Out:
#            Genus         Species                      Taxon  IASmean (%)  \
# 35   Adenogramma     teretifolia    Adenogramma teretifolia     0.226999
# 5   Anacampseros       rufescens     Anacampseros rufescens     0.103406
# 23  Anacampseros         subnuda       Anacampseros subnuda     0.120289
# 32   Calandrinia     axilliflora    Calandrinia axilliflora     0.261763
# 18   Calandrinia   colchaguensis  Calandrinia colchaguensis     0.156518
# 22  Calyptridium      umbellatum    Calyptridium umbellatum     0.259478
# 16       Ceraria     fruticulosa        Ceraria fruticulosa     0.149828
# 8      Cistanthe           picta            Cistanthe picta     0.089785
# 36     Cistanthe     salsoloides      Cistanthe salsoloides     0.130410
# 4      Cistanthe         tweedyi          Cistanthe tweedyi     0.179227
# 7      Claytonia      lanceolata       Claytonia lanceolata          NaN
# 26     Claytonia       megarhiza        Claytonia megarhiza     0.310083
# 29      Grahamia       bracteata         Grahamia bracteata     0.241480
# 31    Hypertelis     salsoloides     Hypertelis salsoloides     0.144657
# 11       Lewisia      columbiana         Lewisia columbiana     0.090773
# 6         Limeum       africanum           Limeum africanum     0.080548
# 19        Limeum        subnudum            Limeum subnudum     0.085012
# 25       Mollugo        cerviana           Mollugo cerviana     0.147655
# 10       Mollugo      nudicaulis         Mollugo nudicaulis     0.258841
# 33       Mollugo    verticillata       Mollugo verticillata     0.251497
# 15        Montia        linearis            Montia linearis     0.258567
# 28        Montia      parvifolia          Montia parvifolia     0.241880
# 27    Montiopsis        andicola        Montiopsis andicola     0.112999
# 1     Montiopsis          gayana          Montiopsis gayana     0.232962
# 20    Montiopsis       gilliesii       Montiopsis gilliesii     0.087881
# 12      Pereskia        aculeata          Pereskia aculeata     0.128811
# 24      Pereskia        guamacho          Pereskia guamacho     0.190101
# 9       Pereskia  portulacifolia    Pereskia portulacifolia     0.066218
# 13      Pereskia       sacharosa         Pereskia sacharosa     0.082104
# 3     Pharnaceum         incanum         Pharnaceum incanum     0.127622
# 0     Pharnaceum    microphyllum    Pharnaceum microphyllum     0.055275
# 21  Phemeranthus    teretifolius  Phemeranthus teretifolius     0.091856
# 34     Portulaca        oleracea         Portulaca oleracea     0.145903
# 14  Portulacaria            afra          Portulacaria afra     0.130092
# 2     Quiabentia    verticillata    Quiabentia verticillata     0.160136
# 30       Talinum         caffrum            Talinum caffrum     0.102533
# 17       Talinum      fruticosum         Talinum fruticosum     0.106865
#
#     IASse (%)  LTmean (um)  LTse (um)  MAmean (um^2)  MAse (um^2)  \
# 35   0.059778   121.342000   2.023269     313.217133    17.372898
# 5    0.031097          NaN        NaN    7170.181933  1008.100584
# 23   0.021124          NaN        NaN    4392.562067   563.396753
# 32   0.042780          NaN        NaN            NaN          NaN
# 18   0.047394          NaN        NaN            NaN          NaN
# 22   0.019914          NaN        NaN            NaN          NaN
# 16   0.056282          NaN        NaN            NaN          NaN
# 8    0.032958          NaN        NaN            NaN          NaN
# 36   0.012014          NaN        NaN            NaN          NaN
# 4    0.042938          NaN        NaN            NaN          NaN
# 7         NaN          NaN        NaN    1332.231533    66.213801
# 26   0.043321   811.019333  39.394051    3233.608800   228.313502
# 29   0.047252          NaN        NaN            NaN          NaN
# 31   0.021089          NaN        NaN     837.148700    40.577114
# 11   0.033337          NaN        NaN            NaN          NaN
# 6    0.014767          NaN        NaN            NaN          NaN
# 19   0.030895   220.380000  10.375583     552.450600    30.266382
# 25        NaN          NaN        NaN     375.818182    39.853750
# 10        NaN   141.333667   2.222333     523.170400    47.478094
# 33   0.052205   334.435000   9.070028     779.793450    80.281081
# 15   0.029304          NaN        NaN    1242.919300    73.475659
# 28   0.034137   359.432667  23.462268    1818.223100    85.885626
# 27   0.004506          NaN        NaN     991.604200    65.798550
# 1    0.054896          NaN        NaN     878.391200    43.539876
# 20   0.019629          NaN        NaN     574.544800    51.273449
# 12   0.022960          NaN        NaN            NaN          NaN
# 24   0.015139          NaN        NaN    6375.642400   736.145464
# 9    0.025064          NaN        NaN    1525.653000   155.040657
# 13   0.017780          NaN        NaN    1422.369000    92.769926
# 3    0.008834          NaN        NaN     627.360200    38.991692
# 0    0.006720          NaN        NaN     894.747800    56.259644
# 21   0.023772          NaN        NaN            NaN          NaN
# 34   0.036803          NaN        NaN     850.859867    76.449975
# 14   0.036842          NaN        NaN            NaN          NaN
# 2    0.047738          NaN        NaN   10850.909133   813.031276
# 30   0.014480          NaN        NaN            NaN          NaN
# 17   0.009108          NaN        NaN            NaN          NaN
#
#                                             Reference MajorLineage
# 35  Ogburns and Edwards (2012); Ogburns and Edward...          NaN
# 5   Ogburns and Edwards (2012); Ogburns and Edward...
# 23  Ogburns and Edwards (2012); Ogburns and Edward...
# 32  Ogburns and Edwards (2012); Ogburns and Edward...
# 18  Ogburns and Edwards (2012); Ogburns and Edward...
# 22  Ogburns and Edwards (2012); Ogburns and Edward...
# 16  Ogburns and Edwards (2012); Ogburns and Edward...
# 8   Ogburns and Edwards (2012); Ogburns and Edward...
# 36  Ogburns and Edwards (2012); Ogburns and Edward...
# 4   Ogburns and Edwards (2012); Ogburns and Edward...
# 7   Ogburns and Edwards (2012); Ogburns and Edward...          NaN
# 26  Ogburns and Edwards (2012); Ogburns and Edward...          NaN
# 29  Ogburns and Edwards (2012); Ogburns and Edward...
# 31  Ogburns and Edwards (2012); Ogburns and Edward...
# 11  Ogburns and Edwards (2012); Ogburns and Edward...
# 6   Ogburns and Edwards (2012); Ogburns and Edward...
# 19  Ogburns and Edwards (2012); Ogburns and Edward...          NaN
# 25  Ogburns and Edwards (2012); Ogburns and Edward...
# 10  Ogburns and Edwards (2012); Ogburns and Edward...          NaN
# 33  Ogburns and Edwards (2012); Ogburns and Edward...
# 15  Ogburns and Edwards (2012); Ogburns and Edward...
# 28  Ogburns and Edwards (2012); Ogburns and Edward...
# 27  Ogburns and Edwards (2012); Ogburns and Edward...
# 1   Ogburns and Edwards (2012); Ogburns and Edward...
# 20  Ogburns and Edwards (2012); Ogburns and Edward...
# 12  Ogburns and Edwards (2012); Ogburns and Edward...
# 24  Ogburns and Edwards (2012); Ogburns and Edward...
# 9   Ogburns and Edwards (2012); Ogburns and Edward...
# 13  Ogburns and Edwards (2012); Ogburns and Edward...
# 3   Ogburns and Edwards (2012); Ogburns and Edward...
# 0   Ogburns and Edwards (2012); Ogburns and Edward...
# 21  Ogburns and Edwards (2012); Ogburns and Edward...
# 34  Ogburns and Edwards (2012); Ogburns and Edward...
# 14  Ogburns and Edwards (2012); Ogburns and Edward...
# 2   Ogburns and Edwards (2012); Ogburns and Edward...
# 30  Ogburns and Edwards (2012); Ogburns and Edward...
# 17  Ogburns and Edwards (2012); Ogburns and Edward...

# %%
mogs = mogs.append(miscOgs)

# %%
mogs.loc[mogs["Genus"].isin(["Adenogramma","Hypertelis","Mollugo","Pharnaceum"]), "MajorLineage"] = "Molluginaceae"
mogs.loc[mogs["Genus"].isin(["Alluaudia","Portulacaria","Ceraria"]), "MajorLineage"] = "Didiereaceae"
mogs.loc[mogs["Genus"].isin(["Anacampseros","Grahamia","Talinopsis"]), "MajorLineage"] = "Anacampserotaceae"
mogs.loc[mogs["Genus"].isin(["Anredera","Basella"]), "MajorLineage"] = "Basellaceae"
mogs.loc[mogs["Genus"].isin(["Calandrinia","Calyptridium","Cistanthe","Claytonia","Lewisia", "Montia","Montiopsis","Phemeranthus"]), "MajorLineage"] = "Montiaceae"
mogs.loc[mogs["Genus"].isin(["Halophytum"]), "MajorLineage"] = "Halophytaceae"
mogs.loc[mogs["Genus"].isin(["Limeum"]), "MajorLineage"] = "Limeaceae"
mogs.loc[mogs["Genus"].isin(["Mirabilis"]), "MajorLineage"] = "Nyctaginaceae"
mogs.loc[mogs["Genus"].isin(["Pereskia","Quiabentia"]), "MajorLineage"] = "Cactaceae"
mogs.loc[mogs["Genus"].isin(["Portulaca"]), "MajorLineage"] = "Portulacaceae"
mogs.loc[mogs["Genus"].isin(["Talinum"]), "MajorLineage"] = "Talinaceae"

mogs.loc[mogs["MajorLineage"].isin(["Anacampserotaceae", "Basellaceae", "Talinaceae", ]), "Pathway"] = "C3+CAM"
mogs.loc[mogs["Taxon"].isin(["Anacampseros subnuda",]), "Pathway"] = "CAM"
mogs.loc[mogs["Genus"].isin(["Pereskia","Portulacaria","Cistanthe","Ceraria","Halophytum","Calyptridium","Calandrinia","Phemeranthus","Quiabentia", "Lewisia",]), "Pathway"] = "C3+CAM"
mogs.loc[mogs["Genus"].isin(["Alluaudia",]), "Pathway"] = "CAM"
mogs.loc[mogs["Genus"].isin(["Montia","Limeum","Claytonia","Mirabilis", "Montiopsis"]), "Pathway"] = "C3"
mogs.loc[mogs["Taxon"].isin(["Calandrinia tumida"]), "Pathway"] = "C3"
mogs.loc[mogs["Genus"].isin(["Portulaca",]), "Pathway"] = "C4+CAM"
mogs.loc[mogs["MajorLineage"].isin(["Molluginaceae"]), "Pathway"] = "C3"
mogs.loc[mogs["Taxon"].isin(["Mollugo verticillata", "Mollugo cerviana"]), "Pathway"] = "C3-C4"
mogs["Tissue"] = "leaf"
mogs["Source"] = "Ogburn"

# %%
mogs.groupby("Taxon").mean().reset_index().merge(mogs[["Taxon","Pathway"]],on="Taxon")["Pathway"].value_counts()
# Out:
# C3+CAM    46
# C3        26
# C3-C4      4
# CAM        3
# C4+CAM     3
# Name: Pathway, dtype: int64

# %% [markdown]
# ### TRY database
# These data were accessed via the TRY database of plant traits

# %%
tryLDMC = pd.read_csv("../Data/TRY-Database/LDMC.csv")
tryLDMC = tryLDMC.rename({"LDMC_gg-1": "LDMCmean (g/g)", "LDMC_gg-1_SE":"LDMCse (g/g)"}, axis=1)
tryLT = pd.read_csv("../Data/TRY-Database/Leaf-Thickness.csv")
tryLT = tryLT.rename({"leaf_thickness_um":"LTmean (um)","leaf_thickness_um_SE":"LTse (um)"}, axis=1)
tryDF = tryLDMC.merge(tryLT, how="outer")
tryMA = pd.read_csv("../Data/TRY-Database/Mesophyll-Cell-Area.csv")
tryMA = tryMA.rename({"mesophyll_cell_area_um2":"MAmean (um^2)","mesophyll_cell_area_um2_SE":"MAse (um^2)"}, axis=1)
tryDF = tryDF.merge(tryMA, how="outer")
tryDSLA = pd.read_csv("../Data/TRY-Database/SLA-Dry-Mass.csv")
tryDSLA = tryDSLA.rename({"SLAd_mm2mg-1":"dSLAmean (mm^2/mg)","SLAd_mm2mg-1_SE":"dSLAse (mm^2/mg)"}, axis=1)
tryDF = tryDF.merge(tryDSLA, how="outer")
tryFSLA = pd.read_csv("../Data/TRY-Database/SLA-Fresh-Mass.csv")
tryFSLA = tryFSLA.rename({"SLAf_mm2mg-1":"fSLAmean (mm^2/mg)","SLAf_mm2mg-1_SE":"fSLAse (mm^2/mg)"}, axis=1)
tryDF = tryDF.merge(tryFSLA, how="outer")
tryDF = tryDF.rename({"Family":"MajorLineage"}, axis=1)

# %%
tryIAS = pd.read_csv("../Data/TRY-Database/IAS.csv")
tryIAS = tryIAS.rename({"IASmean (%)": "IAS (%)"}, axis=1)
tryIAS["IAS (%)"] = tryIAS["IAS (%)"]/100
tryIAS.head()
# Out:
#   MajorLineage             Taxon  IAS (%)  \
# 0   Solanaceae   Solanum arcanum    0.367
# 1   Solanaceae   Solanum arcanum    0.411
# 2   Solanaceae   Solanum arcanum    0.186
# 3   Solanaceae   Solanum arcanum    0.301
# 4   Solanaceae  Solanum chilense    0.330
#
#                                            Reference
# 0  Muir CD, RP Hangarter, LC Moyle & PA Davis (20...
# 1  Muir CD, RP Hangarter, LC Moyle & PA Davis (20...
# 2  Muir CD, RP Hangarter, LC Moyle & PA Davis (20...
# 3  Muir CD, RP Hangarter, LC Moyle & PA Davis (20...
# 4  Muir CD, RP Hangarter, LC Moyle & PA Davis (20...

# %%
IASmean = []
IASse = []
taxon = []
for t in tryIAS.Taxon.unique():
    taxon.append(t)
    IASmean.append(tryIAS[tryIAS["Taxon"]==t]["IAS (%)"].mean())
    IASse.append(stats.sem(tryIAS[tryIAS["Taxon"]==t]["IAS (%)"]))
tryIASmeans = pd.DataFrame()
tryIASmeans["Taxon"] = taxon
tryIASmeans["IASmean (%)"] = IASmean
tryIASmeans["IASse (%)"] = IASse
tryIASmeans["Genus"] = [t[0] for t in tryIASmeans["Taxon"].str.split()]
tryIASmeans["Species"] = [t[1] for t in tryIASmeans["Taxon"].str.split()]
tryIASmeans["Pathway"] = "C3"
tryIASmeans["Tissue"] = "leaf"
tryIASmeans["Reference"] = tryIAS["Reference"][0]
tryIASmeans["MajorLineage"] = "Solanaceae"
tryIASmeans.head()
# Out:
#                   Taxon  IASmean (%)  IASse (%)    Genus       Species  \
# 0       Solanum arcanum     0.316250   0.048948  Solanum       arcanum
# 1      Solanum chilense     0.295571   0.017120  Solanum      chilense
# 2   Solanum galapagense     0.302000   0.025811  Solanum   galapagense
# 3  Solanum habrochaites     0.196800   0.029562  Solanum  habrochaites
# 4   Solanum huaylasense     0.298600   0.019038  Solanum   huaylasense
#
#   Pathway Tissue                                          Reference  \
# 0      C3   leaf  Muir CD, RP Hangarter, LC Moyle & PA Davis (20...
# 1      C3   leaf  Muir CD, RP Hangarter, LC Moyle & PA Davis (20...
# 2      C3   leaf  Muir CD, RP Hangarter, LC Moyle & PA Davis (20...
# 3      C3   leaf  Muir CD, RP Hangarter, LC Moyle & PA Davis (20...
# 4      C3   leaf  Muir CD, RP Hangarter, LC Moyle & PA Davis (20...
#
#   MajorLineage
# 0   Solanaceae
# 1   Solanaceae
# 2   Solanaceae
# 3   Solanaceae
# 4   Solanaceae

# %%
tryDF = tryDF.merge(tryIASmeans, how="outer")
tryDF["color"] = [cmap[p] for p in tryDF["Pathway"]]
tryDF["Tissue"] = "leaf"
tryDF["Source"] = "TRY"
tryDF.head()
# Out:
#               Taxon  LDMCmean (g/g)  LDMCse (g/g)    MajorLineage   Genus  \
# 0    Abelia biflora        0.263048  2.484984e-12  Caprifoliaceae  Abelia
# 1        Abies alba        0.330752  2.804777e-02        Pinaceae   Abies
# 2    Abies concolor        0.452686  1.044235e-02        Pinaceae   Abies
# 3  Abies lasiocarpa        0.508283  6.413033e-03        Pinaceae   Abies
# 4     Acacia aneura        0.300780  2.692856e-02        Fabaceae  Acacia
#
#   Pathway                                          Reference     Species  \
# 0      C3  Wang, Han; Harrison, Sandy P; Prentice, Iain C...     biflora
# 1      C3  Reich, P. B., J. Oleksyn, and I. J. Wright. 20...        alba
# 2      C3  Laughlin, D.C., P.Z. Fulé, D.W. Huffman, J. Cr...    concolor
# 3      C3  Cornwell, W. K., J. H. C. Cornelissen, K. Amat...  lasiocarpa
# 4      C3  Cornwell WK, Wright I, Turner J, Maire V, Barb...      aneura
#
#    LTmean (um)  LTse (um)  ...  MAse (um^2)  dSLAmean (mm^2/mg)  \
# 0          NaN        NaN  ...          NaN           20.279533
# 1   569.716429  16.024899  ...          NaN            6.020967
# 2   596.500000  21.512236  ...          NaN            7.046874
# 3   758.750000  15.860722  ...          NaN           20.194931
# 4   495.833333        NaN  ...          NaN            2.598784
#
#    dSLAse (mm^2/mg)  fSLAmean (mm^2/mg)  fSLAse (mm^2/mg)  IASmean (%)  \
# 0               NaN                 NaN               NaN          NaN
# 1          1.694338                 NaN               NaN          NaN
# 2          0.107726                 NaN               NaN          NaN
# 3          1.393947                 NaN               NaN          NaN
# 4          0.280178            2.974073          0.126443          NaN
#
#    IASse (%)  Tissue                color Source
# 0        NaN    leaf  xkcd:light eggplant    TRY
# 1        NaN    leaf  xkcd:light eggplant    TRY
# 2        NaN    leaf  xkcd:light eggplant    TRY
# 3        NaN    leaf  xkcd:light eggplant    TRY
# 4        NaN    leaf  xkcd:light eggplant    TRY
#
# [5 rows x 21 columns]

# %%
tryDF[["Taxon","Pathway"]].drop_duplicates()["Pathway"].value_counts()
# Out:
# C3        4624
# C4         217
# CAM         19
# C3+CAM       8
# C4+CAM       1
# Name: Pathway, dtype: int64

# %% [markdown]
# ### BROT 2
# BROT is a database of Mediterranean plant traits (Tavsanoglu _et al._, 2018).

# %%
brot = pd.read_csv("../Data/BROT2_dat.csv")
brot = brot.drop(["ID", "TaxonID", "DataType", "Method", "Region", "Lat", "Long", "Alt", "Comments", "Accuracy"], axis=1)
brot["Genus"] = [t[0] for t in brot["Taxon"].str.split()]
brot["Species"] = [t[1] for t in brot["Taxon"].str.split()]
brot = brot[brot["Trait"].isin(["SLA", "LDMC", "d13C"])]
brot = brot.rename({"SourceID":"Reference"},axis=1)
brot
# Out:
#                              Taxon Trait    Data   Units       Reference  \
# 17                  Sambucus nigra   SLA    20.9  mm2/mg  Mediavilla2003
# 69                  Viburnum tinus   SLA    13.7  mm2/mg       Navas2010
# 123    Mesembryanthemum nodiflorum   SLA   4.775  mm2/mg   Cartagena2017
# 144           Amaranthus blitoides   SLA   20.05  mm2/mg      Bochet2015
# 145           Amaranthus blitoides  LDMC  212.19    mg/g      Bochet2015
# ...                            ...   ...     ...     ...             ...
# 25701               Vitis vinifera   SLA   15.78  mm2/mg      Villar2001
# 25702               Vitis vinifera   SLA   32.57  mm2/mg       Riva2016u
# 25704               Vitis vinifera  LDMC     174    mg/g     Hodgson2017
# 25735              Fagonia cretica   SLA   4.007  mm2/mg  Crevillent2017
# 25760           Zygophyllum fabago   SLA   8.445  mm2/mg   Cartagena2017
#
#                   Genus     Species
# 17             Sambucus       nigra
# 69             Viburnum       tinus
# 123    Mesembryanthemum  nodiflorum
# 144          Amaranthus   blitoides
# 145          Amaranthus   blitoides
# ...                 ...         ...
# 25701             Vitis    vinifera
# 25702             Vitis    vinifera
# 25704             Vitis    vinifera
# 25735           Fagonia     cretica
# 25760       Zygophyllum      fabago
#
# [1592 rows x 7 columns]

# %% [markdown]
# The next data set is a list of genera and families that I've been updating from World Flora Online. Plants Of the World Online (POWO), from Kew, is not a better resource, but this worked easily enough without downloading their massive raw data file.

# %%
wfo = pd.read_csv("../Data/wfoGenusFamilyMap.csv")
wfo.head()
# Out:
#             child           parent
# 0        Honkenya  Caryophyllaceae
# 1    Minuartiella  Caryophyllaceae
# 2  Saxofridericia      Rapateaceae
# 3         Bactria     Polygonaceae
# 4        Petroana  Caryophyllaceae

# %%
brot = brot.merge(wfo, left_on="Genus", right_on="child", how="left")
brot = brot.drop(["child"], axis=1)
brot = brot.rename({"parent":"MajorLineage"}, axis=1)
brot.head()
# Out:
#                          Taxon Trait    Data   Units       Reference  \
# 0               Sambucus nigra   SLA    20.9  mm2/mg  Mediavilla2003
# 1               Viburnum tinus   SLA    13.7  mm2/mg       Navas2010
# 2  Mesembryanthemum nodiflorum   SLA   4.775  mm2/mg   Cartagena2017
# 3         Amaranthus blitoides   SLA   20.05  mm2/mg      Bochet2015
# 4         Amaranthus blitoides  LDMC  212.19    mg/g      Bochet2015
#
#               Genus     Species   MajorLineage
# 0          Sambucus       nigra    Viburnaceae
# 1          Viburnum       tinus      Adoxaceae
# 2  Mesembryanthemum  nodiflorum      Aizoaceae
# 3        Amaranthus   blitoides  Amaranthaceae
# 4        Amaranthus   blitoides  Amaranthaceae

# %%
brotSLA = brot[brot["Trait"]=="SLA"][["MajorLineage", "Genus", "Species", "Taxon", "Data", "Reference"]]
brotSLA = brotSLA.rename({"Data":"dSLAmean (mm^2/mg)"}, axis=1)
brotSLA["Pathway"] = "C3"  
# A few manual changes to pathways
c3Taxa = ["Salsola genistoides", "Senecio gallicus", "Senecio vulgaris", "Euphorbia exigua","Euphorbia falcata","Euphorbia helioscopia",
          "Euphorbia helioscopia", "Euphorbia isatidifolia", "Euphorbia minuta","Euphorbia segetalis","Euphorbia serrata","Euphorbia terracina",
          "Euphorbia terracina", "Euphorbia terracina", ]
c4Taxa = ["Amaranthus blitoides","Atriplex semibaccata", "Salsola kali", "Salsola oppositifolia", ]
c3Genera = ["Geranium","Marrubium",]
c3CAMGenera = ["Sedum",]
c4Genera = ["Cynodon", "Dichanthium","Hyparrhenia","Saccharum"]
brotSLA.loc[brotSLA["Taxon"]=="Mesembryanthemum nodiflorum", "Pathway"] = "C3+CAM"
brotSLA.loc[brotSLA["Taxon"].isin(c3Taxa), "Pathway"] = "C3"
brotSLA.loc[brotSLA["Taxon"].isin(c4Taxa), "Pathway"] = "C4"
brotSLA.loc[brotSLA["Genus"].isin(c3Genera), "Pathway"] = "C3"
brotSLA.loc[brotSLA["Genus"].isin(c3CAMGenera), "Pathway"] = "C3+CAM"
brotSLA.loc[brotSLA["Genus"].isin(c4Genera), "Pathway"] = "C4"
brotSLA["Source"] = "BROT"
brotSLA.head()
# Out:
#     MajorLineage             Genus     Species                        Taxon  \
# 0    Viburnaceae          Sambucus       nigra               Sambucus nigra
# 1      Adoxaceae          Viburnum       tinus               Viburnum tinus
# 2      Aizoaceae  Mesembryanthemum  nodiflorum  Mesembryanthemum nodiflorum
# 3  Amaranthaceae        Amaranthus   blitoides         Amaranthus blitoides
# 5  Amaranthaceae          Atriplex     halimus             Atriplex halimus
#
#   dSLAmean (mm^2/mg)         Reference Pathway Source
# 0               20.9    Mediavilla2003      C3   BROT
# 1               13.7         Navas2010      C3   BROT
# 2              4.775     Cartagena2017  C3+CAM   BROT
# 3              20.05        Bochet2015      C4   BROT
# 5              9.605  NavarroCano2017b      C3   BROT

# %%
brotLDMC = brot[brot["Trait"]=="LDMC"][["MajorLineage", "Genus", "Species", "Taxon", "Data", "Reference"]]
brotLDMC = brotLDMC.rename({"Data":"LDMCmean (g/g)"}, axis=1)
brotLDMC["LDMCmean (g/g)"] = brotLDMC["LDMCmean (g/g)"].astype(float)/1000
brotLDMC["Pathway"] = "C3"
brotLDMC.loc[brotLDMC["Taxon"]=="Mesembryanthemum nodiflorum", "Pathway"] = "C3+CAM"
brotLDMC.loc[brotLDMC["Taxon"].isin(c3Taxa), "Pathway"] = "C3"
brotLDMC.loc[brotLDMC["Taxon"].isin(c4Taxa), "Pathway"] = "C4"
brotLDMC.loc[brotLDMC["Genus"].isin(c3Genera), "Pathway"] = "C3"
brotLDMC.loc[brotLDMC["Genus"].isin(c3CAMGenera), "Pathway"] = "C3+CAM"
brotLDMC.loc[brotLDMC["Genus"].isin(c4Genera), "Pathway"] = "C4"
brotLDMC["Source"] = "BROT"
brotLDMC.head()
# Out:
#       MajorLineage        Genus       Species                 Taxon  \
# 4    Amaranthaceae   Amaranthus     blitoides  Amaranthus blitoides
# 8    Amaranthaceae  Chenopodium         album     Chenopodium album
# 10   Amaranthaceae   Polycnemum         majus      Polycnemum majus
# 15  Amaryllidaceae       Allium  ampeloprasum   Allium ampeloprasum
# 33   Anacardiaceae     Pistacia     lentiscus    Pistacia lentiscus
#
#     LDMCmean (g/g)   Reference Pathway Source
# 4          0.21219  Bochet2015      C4   BROT
# 8          0.21034  Bochet2015      C3   BROT
# 10         0.11375  Bochet2015      C3   BROT
# 15         0.14931  Bochet2015      C3   BROT
# 33         0.44640  Paula2006b      C3   BROT

# %%
brotSLA[["Taxon","Pathway"]].merge(brotLDMC[["Taxon","Pathway"]], on=["Taxon", "Pathway"], how="outer").drop_duplicates()["Pathway"].value_counts()
# Out:
# C3        617
# C4          8
# C3+CAM      2
# Name: Pathway, dtype: int64

# %% [markdown]
# ### Heyduk _et al._ (2016) Agavoideae

# %%
heyduk2016 = pd.read_csv("../Data/Heyduk_etal_2016_anatomy.csv")
heyduk2016["Genus"] = heyduk2016["Genus"].replace("Mafreda", "Manfreda")
heyduk2016["Taxon"] = heyduk2016["Genus"] + " " + heyduk2016["Species"]

genera = []
species = []
pathways = []
ltMeans = []
ltSEs = []
maMeans = []
maSEs = []
iasMeans = []
iasSEs = []
taxa = []

for t in heyduk2016["Taxon"].unique():
    genera.append(t.split()[0])
    species.append(t.split()[1])
    pathways.append(heyduk2016[heyduk2016["Taxon"]==t].Pathway.iloc[0])
    ltMeans.append(heyduk2016[heyduk2016["Taxon"]==t]["LT (um)"].mean())
    ltSEs.append(stats.sem(heyduk2016[heyduk2016["Taxon"]==t]["LT (um)"]))
    maMeans.append(heyduk2016[heyduk2016["Taxon"]==t]["MA (um^2)"].mean())
    maSEs.append(stats.sem(heyduk2016[heyduk2016["Taxon"]==t]["LT (um)"]))
    iasMeans.append(heyduk2016[heyduk2016["Taxon"]==t]["IAS (%)"].mean()/100)
    iasSEs.append(stats.sem(heyduk2016[heyduk2016["Taxon"]==t]["IAS (%)"])/100)
    taxa.append(t)
    
summaryHeyduk2016 = pd.DataFrame(dtype=object)
summaryHeyduk2016["Genus"] = genera
summaryHeyduk2016["Species"] = species
summaryHeyduk2016["Taxon"] = taxa
summaryHeyduk2016["LTmean (um)"] = ltMeans
summaryHeyduk2016["LTse (um)"] = ltSEs
summaryHeyduk2016["MAmean (um^2)"] = maMeans
summaryHeyduk2016["MAse (um^2)"] = maSEs
summaryHeyduk2016["IASmean (%)"] = iasMeans
summaryHeyduk2016["IASse (%)"] = iasSEs
summaryHeyduk2016["Pathway"] = pathways
summaryHeyduk2016["MajorLineage"] = "Agavoideae"
summaryHeyduk2016["Tissue"] = "leaf"
summaryHeyduk2016["Reference"] = "Heyduk et al. (2016)"
summaryHeyduk2016["color"] = [cmap[p] for p in summaryHeyduk2016["Pathway"]]
summaryHeyduk2016["Source"] = "Heyduk et al 2016"
summaryHeyduk2016.head()
# Out:
#           Genus        Species                       Taxon  LTmean (um)  \
# 0         Agave        palmeri               Agave palmeri  1223.101333
# 1         Agave        schotti               Agave schotti  1315.425500
# 2  Beschorneria      yuccoides      Beschorneria yuccoides   793.456733
# 3  Chlorophytum  rhizopendulum  Chlorophytum rhizopendulum   231.494800
# 4    Hesperaloe       funifera         Hesperaloe funifera  1282.351222
#
#     LTse (um)  MAmean (um^2)  MAse (um^2)  IASmean (%)  IASse (%) Pathway  \
# 0         NaN    2835.182233          NaN     0.119167   0.032159     CAM
# 1         NaN    2365.219367          NaN     0.075342   0.011812     CAM
# 2         NaN     836.192233          NaN     0.120494   0.021646  C3+CAM
# 3   15.756147     302.493840    15.756147     0.334074   0.015374      C3
# 4  141.518836     846.192900   141.518836     0.042575   0.002325     CAM
#
#   MajorLineage Tissue             Reference                color  \
# 0   Agavoideae   leaf  Heyduk et al. (2016)          xkcd:lichen
# 1   Agavoideae   leaf  Heyduk et al. (2016)          xkcd:lichen
# 2   Agavoideae   leaf  Heyduk et al. (2016)         xkcd:apricot
# 3   Agavoideae   leaf  Heyduk et al. (2016)  xkcd:light eggplant
# 4   Agavoideae   leaf  Heyduk et al. (2016)          xkcd:lichen
#
#               Source
# 0  Heyduk et al 2016
# 1  Heyduk et al 2016
# 2  Heyduk et al 2016
# 3  Heyduk et al 2016
# 4  Heyduk et al 2016

# %%
heyduk2016[["Taxon","Pathway"]].drop_duplicates()["Pathway"].value_counts()
# Out:
# CAM       8
# C3        3
# C3+CAM    2
# Name: Pathway, dtype: int64

# %% [markdown]
# ### Silvera _et al._ 2005
# This table has additional information on isotopes and titrtable acidty, which need to be dropped, and I've updated the taxonomy in the `Taxon` column, but left the original taxonomy in the `Genus` and `Species` columns. There are also a few species where I could not confidently assign pathways because they did not have titratable acidity data and therefore could have been C3+CAM (many C3+CAM orchids have quite negative isotope values)

# %%
silvera2005 = pd.read_csv("../Data/Silvera-etal-2005.csv")
silvera2005 = silvera2005[["MajorLineage", "Taxon", "LTmean (um)", "LDMCmean (g/g)", "dSLAmean (cm^2/g)", "Pathway", "Reference", "Tissue"]]
silvera2005["dSLAmean (mm^2/mg)"] = silvera2005["dSLAmean (cm^2/g)"]/10
silvera2005 = silvera2005.drop(["dSLAmean (cm^2/g)"], axis=1)
silvera2005["Genus"] = [s.split()[0] for s in silvera2005["Taxon"]]
silvera2005["Species"] = [" ".join(s.split()[1:]) for s in silvera2005["Taxon"]]
silvera2005 = silvera2005.iloc[silvera2005["Pathway"].dropna().index].reset_index(drop=True)
silvera2005["color"] = [cmap[p] for p in silvera2005["Pathway"]]
silvera2005["Source"] = "Silvera et al 2005"
silvera2005.head()
# Out:
#   MajorLineage                  Taxon  LTmean (um)  LDMCmean (g/g) Pathway  \
# 0  Orchidaceae   Acianthera johnsonii       1230.0           0.119      C3
# 1  Orchidaceae            Acineta sp.        550.0           0.141      C3
# 2  Orchidaceae   Anathallis barbulata        630.0           0.172  C3+CAM
# 3  Orchidaceae  Arundina graminifolia        320.0           0.286      C3
# 4  Orchidaceae  Aspasia epidendroides        570.0           0.189  C3+CAM
#
#                Reference Tissue  dSLAmean (mm^2/mg)       Genus  \
# 0  Silvera et al. (2005)   leaf                 8.0  Acianthera
# 1  Silvera et al. (2005)   leaf                19.7     Acineta
# 2  Silvera et al. (2005)   leaf                 7.9  Anathallis
# 3  Silvera et al. (2005)   leaf                11.9    Arundina
# 4  Silvera et al. (2005)   leaf                14.7     Aspasia
#
#          Species                color              Source
# 0      johnsonii  xkcd:light eggplant  Silvera et al 2005
# 1            sp.  xkcd:light eggplant  Silvera et al 2005
# 2      barbulata         xkcd:apricot  Silvera et al 2005
# 3   graminifolia  xkcd:light eggplant  Silvera et al 2005
# 4  epidendroides         xkcd:apricot  Silvera et al 2005

# %%
silvera2005[["Taxon","Pathway"]].drop_duplicates()["Pathway"].value_counts()
# Out:
# C3        101
# C3+CAM     53
# CAM        42
# Name: Pathway, dtype: int64

# %% [markdown]
# ### Males (2018)
# This data set collected by Males (2018) estimated chlorenchyma diameter and thickness, which I'll use to calculate cell area, assuming photosynthetic mesophyll cells are roughly circles. Unfortunately, IAS is given for most species as an absolute area so we cannot use it.

# %%
males2018 = pd.read_csv("../Data/Males-2018.csv")
males2018 = males2018.iloc[males2018["Pathway"].dropna().index].reset_index(drop=True)
males2018["MAmean (um^2)"] = np.pi * ((males2018["ChlorenchymaDiameter (um)"]/2)**2)
males2018 = males2018.drop(["HydrenchymaVerticalThickness (um)", "ChlorenchymaDiameter (um)", "ChlorenchymaVertThickness (um)", "IASmean (um^2)", "ChlorenchymaHydrenchymaRatio", "Subfamily", "Genus", "Species"], axis=1)
males2018["Genus"] = [s.split()[0] for s in males2018["Taxon"]]
males2018["Species"] = [" ".join(s.split()[1:]) for s in males2018["Taxon"]]
males2018["Tissue"] = "leaf"
males2018["color"] = [cmap[p] for p in males2018["Pathway"]]
males2018["IASmean (%)"] = males2018["IASmean (%)"]*0.01
males2018["Source"] = "Males 2018"
males2018.head()
# Out:
#   Pathway                       Taxon     Reference  MajorLineage  \
# 0     CAM  Acanthostachys strobilacea  Males (2018)  Bromeliaceae
# 1     CAM                Aechmea alba  Males (2018)  Bromeliaceae
# 2     CAM       Aechmea bromeliifolia  Males (2018)  Bromeliaceae
# 3     CAM       Aechmea bromeliifolia  Males (2018)  Bromeliaceae
# 4     CAM           Aechmea capixabae  Males (2018)  Bromeliaceae
#
#    LTmean (um)  IASmean (%)  MAmean (um^2)           Genus        Species  \
# 0      3079.47          NaN     650.084191  Acanthostachys    strobilacea
# 1       812.65          NaN     945.145087         Aechmea           alba
# 2      2370.44          NaN    1801.273067         Aechmea  bromeliifolia
# 3      1437.42          NaN    1979.234788         Aechmea  bromeliifolia
# 4       867.96          NaN    1121.614629         Aechmea      capixabae
#
#   Tissue        color      Source
# 0   leaf  xkcd:lichen  Males 2018
# 1   leaf  xkcd:lichen  Males 2018
# 2   leaf  xkcd:lichen  Males 2018
# 3   leaf  xkcd:lichen  Males 2018
# 4   leaf  xkcd:lichen  Males 2018

# %%
males2018[["Taxon","Pathway"]].drop_duplicates()["Pathway"].value_counts()
# Out:
# CAM       84
# C3        67
# C3+CAM     8
# Name: Pathway, dtype: int64

# %% [markdown]
# ### Earnshaw _et al._ 1987
# Again, we're going to drop a fair number of taxa because we canot be certain of C3 vs. C3+CAM

# %%
earnshaw1987 = pd.read_csv("../Data/Earnshaw_etal_1987.csv", usecols=["MajorLineage", "LT (um)", "Tissue", "Reference", "Taxon", "Pathway"])
earnshaw1987 = earnshaw1987.groupby(["MajorLineage", "Tissue", "Reference", "Taxon", "Pathway"]).mean().reset_index()
earnshaw1987["Genus"] = [s.split()[0] for s in earnshaw1987["Taxon"]]
earnshaw1987["Species"] = [" ".join(s.split()[1:]) for s in earnshaw1987["Taxon"]]
earnshaw1987 = earnshaw1987.rename({"LT (um)":"LTmean (um)"},axis=1)
earnshaw1987["Source"] = "Earnshaw et al 1987"
earnshaw1987.head()
# Out:
#   MajorLineage Tissue               Reference                 Taxon Pathway  \
# 0  Apocynaceae   leaf  Earnshaw et al. (1987)   Dischidia imbricata     CAM
# 1    Iridaceae   leaf  Earnshaw et al. (1987)    Libertia pulchella      C3
# 2  Orchidaceae   leaf  Earnshaw et al. (1987)  Agrostophyllum majus      C3
# 3  Orchidaceae   leaf  Earnshaw et al. (1987)    Agrostophyllum sp.      C3
# 4  Orchidaceae   leaf  Earnshaw et al. (1987)   Bryobium eriaeoides  C3+CAM
#
#    LTmean (um)           Genus     Species               Source
# 0       1800.0       Dischidia   imbricata  Earnshaw et al 1987
# 1        200.0        Libertia   pulchella  Earnshaw et al 1987
# 2        280.0  Agrostophyllum       majus  Earnshaw et al 1987
# 3        250.0  Agrostophyllum         sp.  Earnshaw et al 1987
# 4        465.0        Bryobium  eriaeoides  Earnshaw et al 1987

# %%
earnshaw1987[["Taxon","Pathway"]].drop_duplicates()["Pathway"].value_counts()
# Out:
# C3        24
# C3+CAM    19
# CAM       15
# Name: Pathway, dtype: int64

# %% [markdown]
# ## Nelson _et al._ (2008)

# %%
nelson = pd.read_csv("../Data/Nelson2008.csv")
nelson["Genus"] = [s.split()[0] for s in nelson["Taxon"]]
nelson["Species"] = [" ".join(s.split()[1:]) for s in nelson["Taxon"]]
nelson = nelson.merge(wfo, left_on="Genus", right_on="child")
nelson = nelson[['parent','Taxon', 'Genus','Species','LTmean (um)','MAmean (um^2)', 'IASmean (%)', 'Pathway']].rename({'parent':"MajorLineage"},axis=1)
nelson["Tissue"] = "leaf"
nelson["Reference"] = "Nelson et al. (2008)"
nelson["IASmean (%)"] = nelson["IASmean (%)"]/100
nelson["Source"] = "Nelson et al 2008"
nelson.head()
# Out:
#     MajorLineage              Taxon     Genus    Species  LTmean (um)  \
# 0   Asparagaceae    Agave americana     Agave  americana         1210
# 1   Bromeliaceae     Ananas comosus    Ananas    comosus          480
# 2  Asphodelaceae     Aloe pillansii      Aloe  pillansii         2490
# 3   Crassulaceae  Crassula argentea  Crassula   argentea         2220
# 4  Commelinaceae  Callisia fragrans  Callisia   fragrans          370
#
#    MAmean (um^2)  IASmean (%) Pathway Tissue             Reference  \
# 0           2130        0.086     CAM   leaf  Nelson et al. (2008)
# 1            830        0.069     CAM   leaf  Nelson et al. (2008)
# 2           3330        0.128     CAM   leaf  Nelson et al. (2008)
# 3           3270        0.146     CAM   leaf  Nelson et al. (2008)
# 4            610        0.330  C3+CAM   leaf  Nelson et al. (2008)
#
#               Source
# 0  Nelson et al 2008
# 1  Nelson et al 2008
# 2  Nelson et al 2008
# 3  Nelson et al 2008
# 4  Nelson et al 2008

# %%
nelson[["Taxon","Pathway"]].drop_duplicates()["Pathway"].value_counts()
# Out:
# CAM       15
# C3+CAM     4
# C3         4
# C4         4
# Name: Pathway, dtype: int64

# %% [markdown]
# ## Lujan _et al._ (2022)

# %%
lujan = pd.read_csv("../Data/Clusia_leaf_anatomy_summary.csv")
lujan = lujan.rename({"Taxa included in RAD analysis":"TipLabel"},axis=1)

species = []
for t in lujan["TipLabel"]:
    split = t.split("_")
    if split[1] == "sp":
        print(t)
        species.append(" ".join(split[1:]))
    else:
        species.append(split[1])
        
lujan["Species"] = species
lujan["Taxon"] = lujan["Genus"] + " " + lujan["Species"]
lujan = lujan.merge(lujan[["Taxon", "Leaf_thickness", "PM_cell_size"]].groupby("Taxon").agg("mean").reset_index().rename({"Leaf_thickness":"LTmean (um)", "PM_cell_size":"MAmean (um^2)"}, axis=1), on="Taxon")
lujan = lujan[["MajorLineage","Genus","Species","Taxon","LTmean (um)", "MAmean (um^2)", "Pathway"]]
lujan["Reference"] = "Lujan et al. (2022)"
lujan["Tissue"] = "leaf"
lujan = lujan.drop_duplicates().reset_index(drop=True)
lujan["Source"] = "Lujan et al 2022"
lujan
# Out:
# C_sp_484
# C_sp_645
# Chrysochlamys_sp_591c
# Dystovomita_sp_586c
#    MajorLineage        Genus      Species                 Taxon  LTmean (um)  \
# 0    Clusiaceae       Clusia    amazonica      Clusia amazonica        339.5
# 1    Clusiaceae       Clusia   araracuare     Clusia araracuare        726.8
# 2    Clusiaceae       Clusia  brachycarpa    Clusia brachycarpa        352.7
# 3    Clusiaceae       Clusia    coclensis      Clusia coclensis        615.6
# 4    Clusiaceae       Clusia   columnaris     Clusia columnaris        624.4
# ..          ...          ...          ...                   ...          ...
# 60   Clusiaceae  Dystovomita      sp 586c   Dystovomita sp 586c        505.0
# 61   Clusiaceae     Tomovita  caputmonsia  Tomovita caputmonsia        427.5
# 62   Clusiaceae     Tomovita   lanceolata   Tomovita lanceolata        318.8
# 63   Clusiaceae     Tomovita     panamaea     Tomovita panamaea        312.1
# 64   Clusiaceae     Tomovita   weddeliana   Tomovita weddeliana        561.5
#
#     MAmean (um^2) Pathway            Reference Tissue            Source
# 0           657.3  C3+CAM  Lujan et al. (2022)   leaf  Lujan et al 2022
# 1          1278.2  C3+CAM  Lujan et al. (2022)   leaf  Lujan et al 2022
# 2           275.6  C3+CAM  Lujan et al. (2022)   leaf  Lujan et al 2022
# 3          1418.3  C3+CAM  Lujan et al. (2022)   leaf  Lujan et al 2022
# 4          2520.0  C3+CAM  Lujan et al. (2022)   leaf  Lujan et al 2022
# ..            ...     ...                  ...    ...               ...
# 60         1247.5      C3  Lujan et al. (2022)   leaf  Lujan et al 2022
# 61          544.3      C3  Lujan et al. (2022)   leaf  Lujan et al 2022
# 62          796.2      C3  Lujan et al. (2022)   leaf  Lujan et al 2022
# 63          373.0      C3  Lujan et al. (2022)   leaf  Lujan et al 2022
# 64          515.1      C3  Lujan et al. (2022)   leaf  Lujan et al 2022
#
# [65 rows x 10 columns]

# %%
lujan[["Taxon","Pathway"]].drop_duplicates()["Pathway"].value_counts()
# Out:
# C3+CAM    55
# C3         9
# CAM        1
# Name: Pathway, dtype: int64

# %% [markdown]
# ### Combining dataframes

# %%
morph = pd.concat([dbg,elDF,portDF,tryDF, brotSLA, brotLDMC, summaryHeyduk2016, silvera2005, males2018, earnshaw1987, nelson, mogs,lujan])
meanCols = ['IASmean (%)', 'LDMCmean (g/g)', 'LTmean (um)', 'MAmean (um^2)', 'dSLAmean (mm^2/mg)', 'fSLAmean (mm^2/mg)',]
for mc in meanCols:
    morph[mc] = morph[mc].astype(float)
morph["color"] = [cmap[p] for p in morph["Pathway"]]
morph
# Out:
#    MajorLineage        Genus      Species                 Taxon Tissue  \
# 0    Agavoideae        Agave    americana       Agave americana   Leaf
# 1    Agavoideae        Agave    americana       Agave americana   Leaf
# 2    Agavoideae        Agave    americana       Agave americana   Leaf
# 3    Agavoideae        Agave    attenuata       Agave attenuata   Leaf
# 4    Agavoideae        Agave  bovicornuta     Agave bovicornuta   Leaf
# ..          ...          ...          ...                   ...    ...
# 60   Clusiaceae  Dystovomita      sp 586c   Dystovomita sp 586c   leaf
# 61   Clusiaceae     Tomovita  caputmonsia  Tomovita caputmonsia   leaf
# 62   Clusiaceae     Tomovita   lanceolata   Tomovita lanceolata   leaf
# 63   Clusiaceae     Tomovita     panamaea     Tomovita panamaea   leaf
# 64   Clusiaceae     Tomovita   weddeliana   Tomovita weddeliana   leaf
#
#    Pathway  MAmean (um^2)  MAse (um^2)  LTmean (um)   LTse (um)  ...  \
# 0      CAM    1339.683455    20.391867  4887.368333   51.895283  ...
# 1      CAM    2212.446822    36.936013  3204.702000   17.616073  ...
# 2      CAM    3090.210853    53.191428  4402.634667  114.466009  ...
# 3      CAM    3013.052933   175.556512  2935.331667   57.566621  ...
# 4      CAM    3223.139679    84.612126  2729.777000   82.985558  ...
# ..     ...            ...          ...          ...         ...  ...
# 60      C3    1247.500000          NaN   505.000000         NaN  ...
# 61      C3     544.300000          NaN   427.500000         NaN  ...
# 62      C3     796.200000          NaN   318.800000         NaN  ...
# 63      C3     373.000000          NaN   312.100000         NaN  ...
# 64      C3     515.100000          NaN   561.500000         NaN  ...
#
#     IASse (%)            Reference                color            Source  \
# 0    0.013377     This publication          xkcd:lichen               DBG
# 1    0.024675     This publication          xkcd:lichen               DBG
# 2    0.050523     This publication          xkcd:lichen               DBG
# 3         NaN     This publication          xkcd:lichen               DBG
# 4    0.009803     This publication          xkcd:lichen               DBG
# ..        ...                  ...                  ...               ...
# 60        NaN  Lujan et al. (2022)  xkcd:light eggplant  Lujan et al 2022
# 61        NaN  Lujan et al. (2022)  xkcd:light eggplant  Lujan et al 2022
# 62        NaN  Lujan et al. (2022)  xkcd:light eggplant  Lujan et al 2022
# 63        NaN  Lujan et al. (2022)  xkcd:light eggplant  Lujan et al 2022
# 64        NaN  Lujan et al. (2022)  xkcd:light eggplant  Lujan et al 2022
#
#    LDMCmean (g/g)  LDMCse (g/g)  dSLAmean (mm^2/mg)  dSLAse (mm^2/mg)  \
# 0             NaN           NaN                 NaN               NaN
# 1             NaN           NaN                 NaN               NaN
# 2             NaN           NaN                 NaN               NaN
# 3             NaN           NaN                 NaN               NaN
# 4             NaN           NaN                 NaN               NaN
# ..            ...           ...                 ...               ...
# 60            NaN           NaN                 NaN               NaN
# 61            NaN           NaN                 NaN               NaN
# 62            NaN           NaN                 NaN               NaN
# 63            NaN           NaN                 NaN               NaN
# 64            NaN           NaN                 NaN               NaN
#
#     fSLAmean (mm^2/mg)  fSLAse (mm^2/mg)
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ..                 ...               ...
# 60                 NaN               NaN
# 61                 NaN               NaN
# 62                 NaN               NaN
# 63                 NaN               NaN
# 64                 NaN               NaN
#
# [7174 rows x 21 columns]

# %% [markdown]
# I've done my best to catch typos, spelling errors, and fill in missing information. An final version of the dataset is available in this repo (`All-morphological-data.csv`), but I wanted to show how I treated the raw data.

# %%
morph.loc[morph["Genus"]=="Aphananthe", "MajorLineage"] = "Cannabaceae"
morph.loc[morph["Taxon"]=="Argyrodendron peralatum", "Taxon"] = "Heritiera peralata"
morph.loc[morph["Taxon"]=="Heritiera peralata", "MajorLineage"] = "Malvaceae"
morph.loc[morph["Taxon"]=="Blechnum penna-marina", "MajorLineage"] = "Aspleniaceae"
morph.loc[morph["Taxon"]=="Clarisia racemosa", "MajorLineage"] = "Moraceae"
morph.loc[morph["Taxon"]=="Coronopus didymus", "MajorLineage"] = "Brassicaceae"
morph.loc[morph["Taxon"]=="Coronopus didymus", "Taxon"] = "Lepidium didymum"
morph.loc[morph["Taxon"]=="Dactylus glomerata", "MajorLineage"] = "Poaceae"
morph.loc[morph["Taxon"]=="Dactylus glomerata", "Taxon"] = "Dactylis glomerata"
morph.loc[morph["Taxon"]=="Evodia fargesii", "MajorLineage"] = "Rutaceae"
morph.loc[morph["Taxon"]=="Evodia fargesii", "Taxon"] = "Tetradium glabrifolium"
morph.loc[morph["Taxon"]=="Evodia lepta", "MajorLineage"] = "Rutaceae"
morph.loc[morph["Taxon"]=="Evodia lepta", "Taxon"] = "Melicope pteleifolia"
morph.loc[morph["Taxon"]=="Glaux maritima", "MajorLineage"] = "Primulaceae"
morph.loc[morph["Taxon"]=="Glaux maritima", "Taxon"] = "Lysimachia maritima"
morph.loc[morph["Taxon"]=="Lloydia serotina", "MajorLineage"] = "Liliaceae"
morph.loc[morph["Taxon"]=="Lloydia serotina", "Taxon"] = "Gagea serotina"
morph.loc[morph["Taxon"]=="Manglietia insignis", "MajorLineage"] = "Magnoliaceae"
morph.loc[morph["Taxon"]=="Manglietia insignis", "Taxon"] = "Magnolia insignis"
morph.loc[morph["Taxon"]=="Michelia champaca", "MajorLineage"] = "Magnoliaceae"
morph.loc[morph["Taxon"]=="Michelia champaca", "Taxon"] = "Magnolia champaca"
morph.loc[morph["Taxon"]=="Pernettya alpina", "MajorLineage"] = "Ericaceae"
morph.loc[morph["Taxon"]=="Pernettya alpina", "Taxon"] = "Gaultheria nubicola"
morph.loc[morph["Taxon"]=="Rapanea melanophloeos", "MajorLineage"] = "Primulaceae"
morph.loc[morph["Taxon"]=="Rapanea melanophloeos", "Taxon"] = "Myrsine melanophloeos"
morph.loc[morph["Taxon"]=="Regelia ciliata", "MajorLineage"] = "Myrtaceae"
morph.loc[morph["Taxon"]=="Regelia ciliata", "Taxon"] = "Melaleuca crossota"
morph.loc[morph["Taxon"]=="Agave americana", "MajorLineage"] = "Agavoideae"

morph.loc[morph["Taxon"]=="Sedum album", "Pathway"] = "C3+CAM"
morph.loc[morph["Taxon"]=="Tectaria dracontifolia", "MajorLineage"] = "Polypodiaceae"
morph.loc[morph["Taxon"]=="Tectaria dracontifolia", "Taxon"] = "Draconopteris draconoptera"
morph.loc[morph["Taxon"]=="Yucca brevifolia", "Pathway"] = "C3"
morph.loc[morph["Taxon"]=="Mollugo verticillata", "Pathway"] = "C3-C4"
morph.loc[morph["Genus"].isin(["Pereskia", "Ceraria", "Portulacaria", "Pereskiopsis", "Quiabentia", "Umbilicus", "Sedum", "Lewisia", "Codonanthe"]), "Pathway"] = "C3+CAM"
morph.loc[morph["Taxon"].isin(["Crassula helmsii", "Claytonia perfoliata"]), "Pathway"] = "C3+CAM"
morph.loc[morph["Taxon"]=="Atriplex halimus", "Pathway"] = "C4"
morph.loc[morph["Genus"]=="Lygeum", "Pathway"] = "C3"
morph.loc[morph["Genus"]=="Viburnum", "MajorLineage"] = "Adoxaceae"
morph.loc[morph["Genus"]=="Alluaudia", "MajorLineage"] = "Didiereaceae"
morph.loc[morph["Genus"].isin(["Alluaudia","Vanilla"]), "Pathway"] = "CAM"

morph.loc[morph["Taxon"]=="Opuntia salmiana", "Taxon"] = "Salmonopuntia salmiana"
morph.loc[morph["Taxon"]=="Salmonopuntia salmiana", "Species"] = "salmiana"
morph.loc[morph["Taxon"]=="Salmonopuntia salmiana", "Genus"] = "Salmonopuntia"
morph.loc[morph["Taxon"]=="Ariocarpus reustus", "Taxon"] = "Ariocarpus retusus"
morph.loc[morph["Taxon"]=="Ariocarpus retusus", "Species"] = "retusus"
morph.loc[morph["Taxon"]=="Ariocarpus retusus", "Genus"] = "Ariocarpus"
morph.loc[morph["Taxon"]=="Lophocereus gatseii", "Taxon"] = "Lophocereus gatesii"
morph.loc[morph["Taxon"]=="Lophocereus gatesii", "Species"] = "gatesii"
morph.loc[morph["Taxon"]=="Lophocereus gatesii", "Genus"] = "Lophocereus"
morph["Genus"] = [t.split()[0] for t in morph["Taxon"]]
morph["Species"] = [t.split()[1] for t in morph["Taxon"]]
morph["Tissue"] = morph["Tissue"].fillna("leaf")

# %%
nwCalandrinia = ["acaulis","affinis","alba","bracteosa","breweri","caespitosa","carolinii","ciliata","colchaguensis","compacta","conferta","corymbosa","depressa","filifolia","fuegiana",
                 "galapagosa","graminifolia","heterophylla","involucrata","lancifolia","leucopogon","litoralis","minutissima","monandra","nana","nitida","pauciflora","pilosiuscula",
                 "poeppigiana","polyclados","ranunculina","sanguinea","skottsbergii","solisi","spicigera","taltalensis","villaroelii",]
fixCalandrinia = []
for i,row in morph.iterrows():
    if (row["Genus"]=="Calandrinia") and (row["Species"] not in nwCalandrinia):
        fixCalandrinia.append(row["Taxon"].replace("Calandrinia", "Parakeelya"))
    else:
        fixCalandrinia.append(row["Taxon"])
        
morph["Taxon"] = fixCalandrinia
morph["Genus"] = [t.split()[0] for t in morph["Taxon"]]
morph["Species"] = [t.split()[1] for t in morph["Taxon"]]

# %% [markdown]
# Remove gymnosperms

# %%
morph = morph[~morph["MajorLineage"].isin(["Pinaceae","Taxaceae","Zamiaceae", "Gnetaceae","Cupressaceae",
                                                 "Araucariaceae", "Podocarpaceae", "Sciadopityaceae"])] # sorry gymnos
morph[["Taxon","Pathway"]].drop_duplicates()["Pathway"].value_counts()
# Out:
# C3           5098
# CAM           228
# C4            223
# C3+CAM        199
# C4+CAM         11
# C3-C4+CAM       3
# C3-C4           2
# Name: Pathway, dtype: int64

# %% [markdown]
# ### Reducing multiple accessions

# %%
for s in sorted(morph["Source"].unique()):
    print(s)
    print(morph[morph["Source"]==s][["Taxon","Pathway"]].drop_duplicates()["Pathway"].value_counts())
# Out:
# BROT
# C3        602
# C4          9
# C3+CAM      2
# Name: Pathway, dtype: int64
# DBG
# CAM       60
# C3        12
# C3+CAM     7
# Name: Pathway, dtype: int64
# Earnshaw et al 1987
# C3        24
# C3+CAM    19
# CAM       15
# Name: Pathway, dtype: int64
# Edwards Lab unpublished
# C3+CAM    13
# CAM        1
# C3         1
# Name: Pathway, dtype: int64
# Heyduk et al 2016
# CAM       7
# C3        4
# C3+CAM    2
# Name: Pathway, dtype: int64
# Lujan et al 2022
# C3+CAM    55
# C3         9
# CAM        1
# Name: Pathway, dtype: int64
# Males 2018
# CAM       84
# C3        67
# C3+CAM     8
# Name: Pathway, dtype: int64
# Nelson et al 2008
# CAM       14
# C3+CAM     5
# C3         4
# C4         4
# Name: Pathway, dtype: int64
# Ogburn
# C3+CAM    27
# C3        17
# CAM        2
# C3-C4      2
# C4+CAM     2
# Name: Pathway, dtype: int64
# Silvera et al 2005
# C3        101
# C3+CAM     52
# CAM        43
# Name: Pathway, dtype: int64
# TRY
# C3        4501
# C4         216
# C3+CAM      20
# CAM          8
# C4+CAM       1
# C3-C4        1
# Name: Pathway, dtype: int64
# Voznesenskaya
# C4+CAM       11
# C3-C4+CAM     3
# Name: Pathway, dtype: int64

# %%
morph["Tissue"] = morph["Tissue"].str.lower()
morph = morph.drop(morph[(morph["Genus"].isin(["Austrocylindropuntia", "Cylindropuntia"])) & (morph["Tissue"]=="leaf")].index)
morph = morph.drop(morph[(morph["Genus"].isin(["Quiabentia"])) & (morph["Tissue"]=="stem")].index)
reduced = morph.groupby(["MajorLineage", "Taxon", "Tissue", "Pathway"]).mean().reset_index()
reduced = reduced.drop(["MAse (um^2)", "LTse (um)", "IASse (%)"], axis=1)
reduced = reduced[~reduced["MajorLineage"].isin(["Pinaceae","Taxaceae","Zamiaceae", "Gnetaceae","Cupressaceae",
                                                 "Araucariaceae", "Podocarpaceae", "Sciadopityaceae"])] # sorry gymnos
refs = []
camPheno = []
camPhenoCat = []
for i,row in reduced.iterrows():
    refs.append("; ".join(morph[morph["Taxon"]==row["Taxon"]]["Reference"].unique()))
    
    p=row["Pathway"]
    try:
        if p=="CAM":
            camPheno.append("pCAM")
            camPhenoCat.append(2)
        elif "+CAM" in p:
            camPheno.append("mCAM")
            camPhenoCat.append(1)
        else:
            camPheno.append("non-CAM")
            camPhenoCat.append(0)
    except:
        print(p, row["Taxon"])
reduced["CAMpheno"] = camPheno
reduced["CAMphenoCat"] = camPhenoCat    
reduced["Reference"] = refs
reduced["Genus"] = [s.split()[0] for s in reduced["Taxon"]]
reduced["Species"] = [" ".join(s.split()[1:]) for s in reduced["Taxon"]]
reduced["color"] = [cmap[p] for p in reduced["Pathway"]]
reduced = reduced.reset_index(drop=True)
reduced
# Out:
#         MajorLineage                       Taxon Tissue Pathway  \
# 0        Acanthaceae        Acanthopsis disperma   leaf      C3
# 1        Acanthaceae        Acanthus ilicifolius   leaf      C3
# 2        Acanthaceae              Avicennia alba   leaf      C3
# 3        Acanthaceae         Avicennia germinans   leaf      C3
# 4        Acanthaceae            Avicennia lanata   leaf      C3
# ...              ...                         ...    ...     ...
# 5740  Zygophyllaceae         Tribulus terrestris   leaf      C4
# 5741  Zygophyllaceae          Zygophyllum fabago   leaf      C3
# 5742  Zygophyllaceae  Zygophyllum prismatocarpum   leaf      C3
# 5743  Zygophyllaceae     Zygophyllum xanthoxylon   leaf      C3
# 5744  Zygophyllaceae     Zygophyllum xanthoxylum   leaf      C3
#
#       MAmean (um^2)  LTmean (um)  IASmean (%)  LDMCmean (g/g)  LDMCse (g/g)  \
# 0               NaN          NaN          NaN             NaN           NaN
# 1               NaN          NaN          NaN             NaN           NaN
# 2               NaN    370.00000          NaN             NaN           NaN
# 3               NaN          NaN          NaN             NaN           NaN
# 4               NaN          NaN          NaN             NaN           NaN
# ...             ...          ...          ...             ...           ...
# 5740            NaN    217.69875          NaN        0.279749      0.016782
# 5741            NaN          NaN          NaN        0.162882      0.010645
# 5742            NaN          NaN          NaN             NaN           NaN
# 5743            NaN          NaN          NaN        0.140000           NaN
# 5744            NaN          NaN          NaN        0.140000           NaN
#
#       dSLAmean (mm^2/mg)  dSLAse (mm^2/mg)  fSLAmean (mm^2/mg)  \
# 0               5.219207               NaN                 NaN
# 1               2.109827               NaN                 NaN
# 2               6.570000      0.000000e+00                 NaN
# 3               8.580402      3.153483e+00                 NaN
# 4               4.820000      4.905126e-15                 NaN
# ...                  ...               ...                 ...
# 5740           17.793025      1.745367e+00                 NaN
# 5741            6.789692      5.289712e-01                 NaN
# 5742            3.326751      5.794986e-01                 NaN
# 5743                 NaN               NaN                 NaN
# 5744            5.151229               NaN                 NaN
#
#       fSLAse (mm^2/mg) CAMpheno  CAMphenoCat  \
# 0                  NaN  non-CAM            0
# 1                  NaN  non-CAM            0
# 2                  NaN  non-CAM            0
# 3                  NaN  non-CAM            0
# 4                  NaN  non-CAM            0
# ...                ...      ...          ...
# 5740               NaN  non-CAM            0
# 5741               NaN  non-CAM            0
# 5742               NaN  non-CAM            0
# 5743               NaN  non-CAM            0
# 5744               NaN  non-CAM            0
#
#                                               Reference        Genus  \
# 0     Cornwell WK, Wright I, Turner J, Maire V, Barb...  Acanthopsis
# 1     eHALOPH - Halophytes Database (version 3.11) T...     Acanthus
# 2     eHALOPH - Halophytes Database (version 3.11) T...    Avicennia
# 3     eHALOPH - Halophytes Database (version 3.11) T...    Avicennia
# 4     eHALOPH - Halophytes Database (version 3.11) T...    Avicennia
# ...                                                 ...          ...
# 5740  Cornwell WK, Wright I, Turner J, Maire V, Barb...     Tribulus
# 5741  Iversen CM, McCormack ML, Powell AS, Blackwood...  Zygophyllum
# 5742  Cornwell WK, Wright I, Turner J, Maire V, Barb...  Zygophyllum
# 5743  Wang, Han; Harrison, Sandy P; Prentice, Iain C...  Zygophyllum
# 5744  eHALOPH - Halophytes Database (version 3.11) T...  Zygophyllum
#
#              Species                color
# 0           disperma  xkcd:light eggplant
# 1        ilicifolius  xkcd:light eggplant
# 2               alba  xkcd:light eggplant
# 3          germinans  xkcd:light eggplant
# 4             lanata  xkcd:light eggplant
# ...              ...                  ...
# 5740      terrestris  xkcd:light eggplant
# 5741          fabago  xkcd:light eggplant
# 5742  prismatocarpum  xkcd:light eggplant
# 5743     xanthoxylon  xkcd:light eggplant
# 5744     xanthoxylum  xkcd:light eggplant
#
# [5745 rows x 19 columns]

# %%
reduced[["Taxon","Pathway"]].drop_duplicates()["Pathway"].value_counts()
# Out:
# C3           5091
# C4            223
# CAM           222
# C3+CAM        193
# C4+CAM         11
# C3-C4+CAM       3
# C3-C4           2
# Name: Pathway, dtype: int64

# %%
reduced[["Taxon","CAMpheno"]].drop_duplicates()["CAMpheno"].value_counts()
# Out:
# non-CAM    5316
# pCAM        222
# mCAM        207
# Name: CAMpheno, dtype: int64

# %% [markdown]
# This reduced data set will be the basis for downstream analyses.

# %%
# reduced.to_csv("../Data/Merged/All-morphological-data.csv", index=False)
# reduced = pd.read_csv("../Data/Merged/All-morphological-data.csv")

# %%
reduced[["Taxon","CAMpheno"]].drop_duplicates()["CAMpheno"].value_counts()
# Out:
# non-CAM    5316
# pCAM        222
# mCAM        207
# Name: CAMpheno, dtype: int64

# %% [markdown]
# ### Data for phylogenetic analysis
# Now I'll take our final time calibrated tree and pull anatomical data for the species it contains for phylogenetic analysis in `R`.

# %%
import toytree as tt
import toyplot as tp

# %%
tree = tt.tree("../Results/PhyloWeld.timetree.nwk")

# %%
tipLabs = []
genera = []
species = []
accNos = []
datasets = []
mls = []
for t in tree.get_tip_labels():
    tipLabs.append(t)
    split = t.split("_")
    g = split[0]
    if split[1] in ["sp", "cf"]:
        s = " ".join(split[1:-1])        
    elif split[1].isnumeric():
        s = ""
    elif "grandiflora_or_procumbens" in t:
        s = "pilosiuscula"
    else:
        s = split[1]
    if split[-1].isnumeric():
        an = split[-1]
        ds = "Edwards"
    else:
        an = None
        ds = "Wang"
    
    genera.append(g)
    species.append(s)
    accNos.append(an)
    datasets.append(ds)
    mls.append(wfo[wfo["child"]==g]["parent"].values[0])

treeDF = pd.DataFrame()
treeDF["tipLabel"] = tipLabs
treeDF["MajorLineage"] = mls
treeDF["Genus"] = genera
treeDF["Species"] = species
treeDF["accNo"] = accNos
treeDF["Dataset"] = datasets
treeDF
# Out:
#                           tipLabel        MajorLineage         Genus  \
# 0          Calandrinia_creethae_39          Montiaceae   Calandrinia
# 1         Calandrinia_creethae_161          Montiaceae   Calandrinia
# 2       Calandrinia_stagnensis_101          Montiaceae   Calandrinia
# 3         Calandrinia_mirabilis_85          Montiaceae   Calandrinia
# 4      Calandrinia_quadrivalvis_26          Montiaceae   Calandrinia
# ..                             ...                 ...           ...
# 248            Mollugo_pentaphylla       Molluginaceae       Mollugo
# 249      Stegnosperma_halimifolium  Stegnospermataceae  Stegnosperma
# 250             Limeum_aethiopicum           Limeaceae        Limeum
# 251     Beta_vulgaris_vulgaris_cds       Amaranthaceae          Beta
# 252  Amaranthus_hypochondriacus_tr       Amaranthaceae    Amaranthus
#
#              Species accNo  Dataset
# 0           creethae    39  Edwards
# 1           creethae   161  Edwards
# 2         stagnensis   101  Edwards
# 3          mirabilis    85  Edwards
# 4       quadrivalvis    26  Edwards
# ..               ...   ...      ...
# 248      pentaphylla  None     Wang
# 249     halimifolium  None     Wang
# 250      aethiopicum  None     Wang
# 251         vulgaris  None     Wang
# 252  hypochondriacus  None     Wang
#
# [253 rows x 6 columns]

# %% [markdown]
# I've got to do a little work to bring the taxonomy and spelling to match the anatomical data. Note that, for ease, I've left some old taxonomies in place (e.g., _Ceraria_ instead of _Portulacaria_) because they are consistent between tree and data frame. I'm also going to add a boolean `Drop` column that will be used later in `R` to reduce the tree to one accession per species.

# %%
treeDF.loc[(treeDF["Genus"]=="Salmiopuntia") & (treeDF["Species"]=="salmiana"), "Genus"] = "Salmonopuntia"
treeDF.loc[treeDF["Species"]=="gatesii", "Genus"] = "Lophocereus"
treeDF.loc[(treeDF["Genus"]=="Talinella"), "Species"] = "pachypodum"
treeDF.loc[(treeDF["Genus"]=="Talinella"), "Genus"] = "Talinum"
treeDF.loc[(treeDF["Genus"]=="Montia") & (treeDF["Species"]=="parviflora"), "Species"] = "parvifolia"
treeDF.loc[(treeDF["Genus"]=="Suessenguthiella"), "Species"] = "scleranthoides"
treeDF.loc[(treeDF["Genus"]=="Mollugo") & (treeDF["Species"]=="cerviana"), "Genus"] = "Paramollugo"
treeDF.loc[(treeDF["Genus"]=="Glinus"), "Species"] = "lotoides"
treeDF.loc[(treeDF["Genus"]=="Leuenbergeria"), "Genus"] = "Pereskia"
treeDF.loc[(treeDF["Genus"]=="Calandrinia") & (treeDF["Species"]=="eremea"), "Species"] = "eremaea"
treeDF.loc[treeDF["Species"]=="colchagensis", "Species"] = "colchaguensis"

fixCalandrinia = []
for i,row in treeDF.iterrows():
    if (row["Genus"]=="Calandrinia") and (row["Species"] not in nwCalandrinia):
        fixCalandrinia.append("Parakeelya")
    else:
        fixCalandrinia.append(row["Genus"])

treeDF["Genus"] = fixCalandrinia
treeDF["Taxon"] = treeDF["Genus"] + " " + treeDF["Species"]
treeDF["Taxon"] = treeDF["Taxon"].str.strip()
treeDF["Drop"] = treeDF.duplicated(subset=["Taxon"])
toDrop = ["Alluaudia_procera_53", "Alluaudia_dumosa_65", "Portulaca_sp_221"]
treeDF.loc[treeDF["tipLabel"].isin(toDrop), "Drop"] = True
treeDF.loc[treeDF["Species"] == "sp", "Drop"] = True
treeDF
# Out:
#                           tipLabel        MajorLineage         Genus  \
# 0          Calandrinia_creethae_39          Montiaceae    Parakeelya
# 1         Calandrinia_creethae_161          Montiaceae    Parakeelya
# 2       Calandrinia_stagnensis_101          Montiaceae    Parakeelya
# 3         Calandrinia_mirabilis_85          Montiaceae    Parakeelya
# 4      Calandrinia_quadrivalvis_26          Montiaceae    Parakeelya
# ..                             ...                 ...           ...
# 248            Mollugo_pentaphylla       Molluginaceae       Mollugo
# 249      Stegnosperma_halimifolium  Stegnospermataceae  Stegnosperma
# 250             Limeum_aethiopicum           Limeaceae        Limeum
# 251     Beta_vulgaris_vulgaris_cds       Amaranthaceae          Beta
# 252  Amaranthus_hypochondriacus_tr       Amaranthaceae    Amaranthus
#
#              Species accNo  Dataset                       Taxon   Drop
# 0           creethae    39  Edwards         Parakeelya creethae  False
# 1           creethae   161  Edwards         Parakeelya creethae   True
# 2         stagnensis   101  Edwards       Parakeelya stagnensis  False
# 3          mirabilis    85  Edwards        Parakeelya mirabilis  False
# 4       quadrivalvis    26  Edwards     Parakeelya quadrivalvis  False
# ..               ...   ...      ...                         ...    ...
# 248      pentaphylla  None     Wang         Mollugo pentaphylla  False
# 249     halimifolium  None     Wang   Stegnosperma halimifolium  False
# 250      aethiopicum  None     Wang          Limeum aethiopicum  False
# 251         vulgaris  None     Wang               Beta vulgaris  False
# 252  hypochondriacus  None     Wang  Amaranthus hypochondriacus  False
#
# [253 rows x 8 columns]

# %%
prunedTree = tree.drop_tips(names=list(treeDF[treeDF["Drop"]==True]["tipLabel"].values))

# %% [markdown]
# ### Data imputation
# I'm now going to create the final anatomical data set for phylogenetic analysis using a little imputation for genera that we have in our tree that do not had _species specific data already_. For example, the taxon _Copiapoa desertorum_ is in our tree, but we only have anatomical data from _Copiapoa rupestris_, so I will use data from _Copiapoa ruprestris_ to represent _Copiapoa_ in our tree. I will not impute data for any genera that already have species specific data; the tree will simply be pruned in `R` to remove those species without data.

# %%
dataCols = ["MAmean (um^2)", "LTmean (um)","IASmean (%)"]

# %%
noImpute = treeDF[treeDF["Drop"]==False].merge(reduced, on=["MajorLineage","Taxon","Genus","Species"], how="left")
noImpute = noImpute[["tipLabel","MajorLineage","Genus","Species","Taxon","Pathway","MAmean (um^2)", "LTmean (um)","IASmean (%)"]]
noImpute.loc[noImpute["MajorLineage"].isin(["Cactaceae", "Didiereaceae"]), "Pathway"] = "CAM"
noImpute.loc[noImpute["MajorLineage"].isin(["Anacampserotaceae","Basellaceae","Montiaceae","Talinaceae"]), "Pathway"] = "C3+CAM"
noImpute.loc[noImpute["Genus"].isin(["Pereskia","Delosperma", "Pereskiopsis", "Quiabentia", "Portulacaria", "Ceraria", "Didierea", ]), "Pathway"] = "C3+CAM"
noImpute.loc[noImpute["Genus"].isin(["Portulaca","Sesuvium"]), "Pathway"] = "C4+CAM"
noImpute.loc[noImpute["Genus"].isin(["Montia","Claytonia","Montiopsis"]), "Pathway"] = "C3"
noImpute.loc[noImpute["Genus"].isin(["Amaranthus",]), "Pathway"] = "C4"
noImpute.loc[noImpute["MajorLineage"].isin(["Molluginaceae","Phytolaccaceae","Limeaceae","Stegnospermataceae","Nyctaginaceae"]), "Pathway"] = "C3"
noImpute.loc[noImpute["Taxon"].isin(["Parakeelya tumida", "Parakeelya granulifera", "Parakeelya arenicola"]), "Pathway"] = "C3"

camPheno = []
camPhenoCat = []
for i,row in noImpute.iterrows():
    p=row["Pathway"]
    try:
        if p=="CAM":
            camPheno.append("pCAM")
            camPhenoCat.append(2)
        elif "+CAM" in p:
            camPheno.append("mCAM")
            camPhenoCat.append(1)
        else:
            camPheno.append("non-CAM")
            camPhenoCat.append(0)
    except:
        print(p, row["Taxon"])
noImpute["CAMpheno"] = camPheno
noImpute["CAMphenoCat"] = camPhenoCat
noImpute.head()
# Out:
#                       tipLabel MajorLineage       Genus       Species  \
# 0      Calandrinia_creethae_39   Montiaceae  Parakeelya      creethae
# 1   Calandrinia_stagnensis_101   Montiaceae  Parakeelya    stagnensis
# 2     Calandrinia_mirabilis_85   Montiaceae  Parakeelya     mirabilis
# 3  Calandrinia_quadrivalvis_26   Montiaceae  Parakeelya  quadrivalvis
# 4   Calandrinia_pleiopetala_74   Montiaceae  Parakeelya   pleiopetala
#
#                      Taxon Pathway  MAmean (um^2)  LTmean (um)  IASmean (%)  \
# 0      Parakeelya creethae  C3+CAM            NaN          NaN          NaN
# 1    Parakeelya stagnensis  C3+CAM            NaN          NaN          NaN
# 2     Parakeelya mirabilis  C3+CAM            NaN          NaN          NaN
# 3  Parakeelya quadrivalvis  C3+CAM    6468.855526  2125.910333     0.296044
# 4   Parakeelya pleiopetala  C3+CAM    6427.563000          NaN     0.076247
#
#   CAMpheno  CAMphenoCat
# 0     mCAM            1
# 1     mCAM            1
# 2     mCAM            1
# 3     mCAM            1
# 4     mCAM            1

# %%
noImpute.describe()
# Out:
#        MAmean (um^2)  LTmean (um)  IASmean (%)  CAMphenoCat
# count      59.000000    40.000000    49.000000   206.000000
# mean     4802.620515  1131.819080     0.152262     1.024272
# std      3371.798393   710.147939     0.083744     0.596243
# min       523.170400   141.333667     0.033634     0.000000
# 25%      1943.398072   621.329692     0.091856     1.000000
# 50%      4222.428571   863.647000     0.128284     1.000000
# 75%      6401.602700  1466.332063     0.207606     1.000000
# max     15824.965100  3736.362667     0.386109     2.000000

# %%
generaWdata = sorted(noImpute.dropna(how="all", subset=dataCols)["Genus"].unique())

# %%
sorted(generaWdata)
# Out:
# ['Alluaudia',
#  'Anacampseros',
#  'Anredera',
#  'Ariocarpus',
#  'Astrophytum',
#  'Calandrinia',
#  'Calyptridium',
#  'Ceraria',
#  'Claytonia',
#  'Echinopsis',
#  'Ferocactus',
#  'Grahamia',
#  'Grusonia',
#  'Gymnocalycium',
#  'Halophytum',
#  'Lewisia',
#  'Lophocereus',
#  'Mollugo',
#  'Montia',
#  'Montiopsis',
#  'Opuntia',
#  'Parakeelya',
#  'Peniocereus',
#  'Pereskia',
#  'Pereskiopsis',
#  'Phemeranthus',
#  'Portulaca',
#  'Portulacaria',
#  'Pterocactus',
#  'Salmonopuntia',
#  'Stetsonia',
#  'Tacinga',
#  'Talinopsis',
#  'Talinum',
#  'Tephrocactus',
#  'Tunilla']

# %%
newData = pd.concat([dbg, elDF, portDF, mogs])
impute = noImpute.copy()
generaWdata = sorted(noImpute.dropna(how="all", subset=dataCols)["Genus"].unique())
for i,row in impute.iterrows():
    common = newData[(newData["Genus"]==row["Genus"]) & (newData["Pathway"]==row["Pathway"])]
    for m in dataCols:
        if (row["MajorLineage"] == "Cactaceae") and (row["Genus"] != "Pereskia") and (m == "LTmean (um)"):
            continue
        elif row["Genus"] in generaWdata:
            continue
        elif (np.isnan(row[m])):
            if len(common[~common[m].isna()])>3:
                mean = common.describe()[m]["mean"]
                std = common.describe()[m]["std"]/np.sqrt(len(common[~common[m].isna()]))
                newVal = np.random.normal(mean,std)
                impute.loc[impute["Taxon"]==row["Taxon"], m] = newVal
                print(row["Taxon"], m)
            elif len(common[~common[m].isna()])>0:
                newVal = common.describe()[m]["mean"]
                impute.loc[impute["Taxon"]==row["Taxon"], m] = newVal
                print(row["Taxon"], m)
            generaWdata.append(row["Genus"])
# Out:
# Cistanthe grandiflora MAmean (um^2)
# Stenocereus yunckeri MAmean (um^2)
# Echinocereus pectinatus MAmean (um^2)
# Copiapoa desertorum MAmean (um^2)
# Quiabentia zehntneri MAmean (um^2)
# Didierea madagascariensis MAmean (um^2)
# Hypertelis walteri MAmean (um^2)
# Pharnaceum exiguum MAmean (um^2)
# Limeum aethiopicum MAmean (um^2)

# %% [markdown]
# So we only imputed mesophyll cell size for 9 species.

# %%
impute.describe()
# Out:
#        MAmean (um^2)  LTmean (um)  IASmean (%)  CAMphenoCat
# count      68.000000    40.000000    49.000000   206.000000
# mean     4635.681723  1131.819080     0.152262     1.024272
# std      3303.491354   710.147939     0.083744     0.596243
# min       523.170400   141.333667     0.033634     0.000000
# 25%      1753.363994   621.329692     0.091856     1.000000
# 50%      4276.038157   863.647000     0.128284     1.000000
# 75%      6379.184117  1466.332063     0.207606     1.000000
# max     15824.965100  3736.362667     0.386109     2.000000

# %%
morphoTips = sorted(impute.dropna(subset=["MAmean (um^2)","LTmean (um)", "IASmean (%)"],how="all")["tipLabel"])

# %%
impute = impute.rename({"MAmean (um^2)":"MA","LTmean (um)":"LT","IASmean (%)":"IAS"},axis=1)

# %%
impute
# Out:
#                           tipLabel        MajorLineage         Genus  \
# 0          Calandrinia_creethae_39          Montiaceae    Parakeelya
# 1       Calandrinia_stagnensis_101          Montiaceae    Parakeelya
# 2         Calandrinia_mirabilis_85          Montiaceae    Parakeelya
# 3      Calandrinia_quadrivalvis_26          Montiaceae    Parakeelya
# 4       Calandrinia_pleiopetala_74          Montiaceae    Parakeelya
# ..                             ...                 ...           ...
# 201            Mollugo_pentaphylla       Molluginaceae       Mollugo
# 202      Stegnosperma_halimifolium  Stegnospermataceae  Stegnosperma
# 203             Limeum_aethiopicum           Limeaceae        Limeum
# 204     Beta_vulgaris_vulgaris_cds       Amaranthaceae          Beta
# 205  Amaranthus_hypochondriacus_tr       Amaranthaceae    Amaranthus
#
#              Species                       Taxon Pathway           MA  \
# 0           creethae         Parakeelya creethae  C3+CAM          NaN
# 1         stagnensis       Parakeelya stagnensis  C3+CAM          NaN
# 2          mirabilis        Parakeelya mirabilis  C3+CAM          NaN
# 3       quadrivalvis     Parakeelya quadrivalvis  C3+CAM  6468.855526
# 4        pleiopetala      Parakeelya pleiopetala  C3+CAM  6427.563000
# ..               ...                         ...     ...          ...
# 201      pentaphylla         Mollugo pentaphylla      C3          NaN
# 202     halimifolium   Stegnosperma halimifolium      C3          NaN
# 203      aethiopicum          Limeum aethiopicum      C3   552.450600
# 204         vulgaris               Beta vulgaris      C3          NaN
# 205  hypochondriacus  Amaranthus hypochondriacus      C4          NaN
#
#               LT       IAS CAMpheno  CAMphenoCat
# 0            NaN       NaN     mCAM            1
# 1            NaN       NaN     mCAM            1
# 2            NaN       NaN     mCAM            1
# 3    2125.910333  0.296044     mCAM            1
# 4            NaN  0.076247     mCAM            1
# ..           ...       ...      ...          ...
# 201          NaN       NaN  non-CAM            0
# 202          NaN       NaN  non-CAM            0
# 203          NaN       NaN  non-CAM            0
# 204          NaN       NaN  non-CAM            0
# 205          NaN       NaN  non-CAM            0
#
# [206 rows x 11 columns]

# %%
# impute.to_csv("../Data/Portullugo-Anatomy-Data.2023-08-09.csv", index=False)

# %% [markdown]
# ## References
# - Ocampo, G. et al. Evolution of leaf anatomy and photosynthetic pathways in Portulacaceae. Am. J. Bot. 100, 2388–2402 (2013).
# - Tavsanoglu Ç. & Pausas J.G. 2018. A functional trait database for Mediterranean Basin plants. Scientific Data 5: 180135.
# - Voznesenskaya, E. V., Koteyeva, N. K., Edwards, G. E. & Ocampo, G. Revealing diversity in structural and biochemical forms of C4 photosynthesis and a C3-C4 intermediate in genus Portulaca L. (Portulacaceae). J. Exp. Bot. 61, 3647–3662 (2010).
# - Voznesenskaya, E. V., Koteyeva, N. K., Edwards, G. E. & Ocampo, G. Unique photosynthetic phenotypes in Portulaca (Portulacaceae): C3-C4 intermediates and NAD-ME C4 species with Pilosoid-type Kranz anatomy. J. Exp. Bot. 68, 225–239 (2017).
